# %% [markdown]
# Import necessary tools

# %%
import pandas as pd
import zipfile
import sqlite3
import os
import scipy.stats as stats
from scipy.stats import norm
from scipy.stats import t
from scipy.stats import ttest_ind
import numpy as np
import seaborn as sns
import random
import math
import recordlinkage
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Check folders

# %%
! ls
# Out:
# Exploratory Notebook-Copy1.ipynb
# Exploratory Notebook.ipynb
# Official Notebook.ipynb
# README.md
# data.sqlite
# extracted_data
# images
# movie_gross_df
# notebooks
# unzipped_data
# zippedData

# %% [markdown]
# Open Box Office Mojo (bom.movie_gross.csv.gz) file

# %%
path = 'zippedData/bom.movie_gross.csv.gz'
movie_gross_df = pd.read_csv('zippedData/bom.movie_gross.csv.gz', compression='gzip', header=0, sep=',', quotechar='"')
conn = sqlite3.connect('data.sqlite')
table_name = 'movie_gross_data'
movie_gross_df.to_sql(table_name, conn, index=False, if_exists='replace')
# Out:
# 3387

# %% [markdown]
# Look into box office mojo file

# %%
movie_gross_df.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
movie_gross_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %% [markdown]
# Open IMDB zip file

# %%
# Step 1: Extract the SQLite database from the zip archive
zip_file_path = 'zippedData/im.db.zip'
extracted_folder = 'extracted_data'

with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extracted_folder)

# %%
# Step 2: Connect to the SQLite database
db_file_path = os.path.join(extracted_folder, 'im.db')
conn = sqlite3.connect(db_file_path)

# %%
# Step 3: Query database using SQL/ pandas to read tables into DataFrames
imdb_basics_df = pd.read_sql(""" 
SELECT *
FROM movie_basics;
""", conn)
imdb_basics_df
# Out:
#          movie_id                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# 2                        The Other Side of the Wind        2018
# 3                                   Sabse Bada Sukh        2018
# 4                             La Telenovela Errante        2017
# ...                                             ...         ...
# 146139                          Kuambil Lagi Hatiku        2019
# 146140  Rodolpho Teóphilo - O Legado de um Pioneiro        2015
# 146141                              Dankyavar Danka        2013
# 146142                                       6 Gunn        2017
# 146143               Chico Albuquerque - Revelações        2013
#
#         runtime_minutes                genres
# 0                 175.0    Action,Crime,Drama
# 1                 114.0       Biography,Drama
# 2                 122.0                 Drama
# 3                   NaN          Comedy,Drama
# 4                  80.0  Comedy,Drama,Fantasy
# ...                 ...                   ...
# 146139            123.0                 Drama
# 146140              NaN           Documentary
# 146141              NaN                Comedy
# 146142            116.0                  None
# 146143              NaN           Documentary
#
# [146144 rows x 6 columns]

# %% [markdown]
# Double check tables

# %%
query_tables = "SELECT name FROM sqlite_master WHERE type='table';"
tables = pd.read_sql(query_tables, conn)
print(tables)
# Out:
#             name
# 0   movie_basics
# 1      directors
# 2      known_for
# 3     movie_akas
# 4  movie_ratings
# 5        persons
# 6     principals
# 7        writers

# %% [markdown]
# Set up dataframes

# %%
dataframes = {}
for table in tables['name']:
    query = f"SELECT * FROM {table};"
    dataframes[table] = pd.read_sql(query, conn)

# %%
imdb_movie_basics_df = dataframes['movie_basics']
imdb_directors_df = dataframes['directors']
imdb_known_for_df = dataframes['known_for']
imdb_movie_akas_df = dataframes['movie_akas']
imdb_movie_ratings_df = dataframes['movie_ratings']
imdb_persons_df = dataframes['persons']
imdb_principals_df = dataframes['principals']
imdb_writers_df = dataframes['writers']

# %% [markdown]
# double check

# %%
imdb_movie_basics_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   movie_id         146144 non-null  object
#  1   primary_title    146144 non-null  object
#  2   original_title   146123 non-null  object
#  3   start_year       146144 non-null  int64
#  4   runtime_minutes  114405 non-null  float64
#  5   genres           140736 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.7+ MB

# %% [markdown]
# Open up TheNumbers movie budgets csv

# %%
path = 'zippedData/tn.movie_budgets.csv.gz'

movie_budget_df = pd.read_csv('zippedData/tn.movie_budgets.csv.gz', compression='gzip', header=0, sep=',', quotechar='"')
conn = sqlite3.connect('data.sqlite')
table_name = 'movie_budget_data'
movie_budget_df.to_sql(table_name, conn, index=False, if_exists='replace')
# Out:
# 5782

# %% [markdown]
# Double check

# %%
movie_budget_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   object
#  4   domestic_gross     5782 non-null   object
#  5   worldwide_gross    5782 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB

# %% [markdown]
# Look at movie gross df

# %%
movie_gross_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %% [markdown]
# Now to merge movie gross, movie budget, and movie basics df together

# %%
gross_budget_merge_df = pd.merge(movie_gross_df, movie_budget_df, how='left', left_on='title', right_on='movie')
gross_budget_merge_df.head()
# Out:
#                                          title studio  domestic_gross_x  \
# 0                                  Toy Story 3     BV       415000000.0
# 1                   Alice in Wonderland (2010)     BV       334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB       296000000.0
# 3                                    Inception     WB       292600000.0
# 4                          Shrek Forever After   P/DW       238700000.0
#
#   foreign_gross  year    id  release_date                movie  \
# 0     652000000  2010  47.0  Jun 18, 2010          Toy Story 3
# 1     691300000  2010   NaN           NaN                  NaN
# 2     664300000  2010   NaN           NaN                  NaN
# 3     535700000  2010  38.0  Jul 16, 2010            Inception
# 4     513900000  2010  27.0  May 21, 2010  Shrek Forever After
#
#   production_budget domestic_gross_y worldwide_gross
# 0      $200,000,000     $415,004,880  $1,068,879,522
# 1               NaN              NaN             NaN
# 2               NaN              NaN             NaN
# 3      $160,000,000     $292,576,195    $835,524,642
# 4      $165,000,000     $238,736,787    $756,244,673

# %%
gross_budget_merge_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3396 entries, 0 to 3395
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              3396 non-null   object
#  1   studio             3391 non-null   object
#  2   domestic_gross_x   3368 non-null   float64
#  3   foreign_gross      2044 non-null   object
#  4   year               3396 non-null   int64
#  5   id                 1247 non-null   float64
#  6   release_date       1247 non-null   object
#  7   movie              1247 non-null   object
#  8   production_budget  1247 non-null   object
#  9   domestic_gross_y   1247 non-null   object
#  10  worldwide_gross    1247 non-null   object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 292.0+ KB

# %%
gross_budget_basics_merge_df = pd.merge(gross_budget_merge_df, imdb_movie_basics_df, how='left', left_on='title', right_on='primary_title')
gross_budget_basics_merge_df.head()
# Out:
#                                          title studio  domestic_gross_x  \
# 0                                  Toy Story 3     BV       415000000.0
# 1                   Alice in Wonderland (2010)     BV       334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB       296000000.0
# 3                                    Inception     WB       292600000.0
# 4                          Shrek Forever After   P/DW       238700000.0
#
#   foreign_gross  year    id  release_date                movie  \
# 0     652000000  2010  47.0  Jun 18, 2010          Toy Story 3
# 1     691300000  2010   NaN           NaN                  NaN
# 2     664300000  2010   NaN           NaN                  NaN
# 3     535700000  2010  38.0  Jul 16, 2010            Inception
# 4     513900000  2010  27.0  May 21, 2010  Shrek Forever After
#
#   production_budget domestic_gross_y worldwide_gross   movie_id  \
# 0      $200,000,000     $415,004,880  $1,068,879,522  tt0435761
# 1               NaN              NaN             NaN        NaN
# 2               NaN              NaN             NaN        NaN
# 3      $160,000,000     $292,576,195    $835,524,642  tt1375666
# 4      $165,000,000     $238,736,787    $756,244,673  tt0892791
#
#          primary_title       original_title  start_year  runtime_minutes  \
# 0          Toy Story 3          Toy Story 3      2010.0            103.0
# 1                  NaN                  NaN         NaN              NaN
# 2                  NaN                  NaN         NaN              NaN
# 3            Inception            Inception      2010.0            148.0
# 4  Shrek Forever After  Shrek Forever After      2010.0             93.0
#
#                        genres
# 0  Adventure,Animation,Comedy
# 1                         NaN
# 2                         NaN
# 3     Action,Adventure,Sci-Fi
# 4  Adventure,Animation,Comedy

# %%
gross_budget_basics_merge_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4175 entries, 0 to 4174
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              4175 non-null   object
#  1   studio             4170 non-null   object
#  2   domestic_gross_x   4140 non-null   float64
#  3   foreign_gross      2539 non-null   object
#  4   year               4175 non-null   int64
#  5   id                 1682 non-null   float64
#  6   release_date       1682 non-null   object
#  7   movie              1682 non-null   object
#  8   production_budget  1682 non-null   object
#  9   domestic_gross_y   1682 non-null   object
#  10  worldwide_gross    1682 non-null   object
#  11  movie_id           3394 non-null   object
#  12  primary_title      3394 non-null   object
#  13  original_title     3394 non-null   object
#  14  start_year         3394 non-null   float64
#  15  runtime_minutes    3222 non-null   float64
#  16  genres             3351 non-null   object
# dtypes: float64(4), int64(1), object(12)
# memory usage: 554.6+ KB

# %% [markdown]
# Now to clean. Start with 'title', 'movie', 'primary_title'

# %% [markdown]
# Strip whitespace

# %%
gross_budget_basics_merge_df['title'] = gross_budget_basics_merge_df['title'].str.strip()

# %%
gross_budget_basics_merge_df['movie'] = gross_budget_basics_merge_df['movie'].str.strip()

# %%
gross_budget_basics_merge_df['primary_title'] = gross_budget_basics_merge_df['primary_title'].str.strip()

# %% [markdown]
# Remove special characters like commas, parentheses, etc. Make lowercase.

# %%
gross_budget_basics_merge_df_copy = gross_budget_basics_merge_df.copy()
gross_budget_basics_merge_df_copy['title'] = gross_budget_basics_merge_df['title'].str.replace('[.,;:\(\)]', '').str.lower()
gross_budget_basics_merge_df_copy.head()
# Out:
#                                          title studio  domestic_gross_x  \
# 0                                  toy story 3     BV       415000000.0
# 1                   alice in wonderland (2010)     BV       334200000.0
# 2  harry potter and the deathly hallows part 1     WB       296000000.0
# 3                                    inception     WB       292600000.0
# 4                          shrek forever after   P/DW       238700000.0
#
#   foreign_gross  year    id  release_date                movie  \
# 0     652000000  2010  47.0  Jun 18, 2010          Toy Story 3
# 1     691300000  2010   NaN           NaN                  NaN
# 2     664300000  2010   NaN           NaN                  NaN
# 3     535700000  2010  38.0  Jul 16, 2010            Inception
# 4     513900000  2010  27.0  May 21, 2010  Shrek Forever After
#
#   production_budget domestic_gross_y worldwide_gross   movie_id  \
# 0      $200,000,000     $415,004,880  $1,068,879,522  tt0435761
# 1               NaN              NaN             NaN        NaN
# 2               NaN              NaN             NaN        NaN
# 3      $160,000,000     $292,576,195    $835,524,642  tt1375666
# 4      $165,000,000     $238,736,787    $756,244,673  tt0892791
#
#          primary_title       original_title  start_year  runtime_minutes  \
# 0          Toy Story 3          Toy Story 3      2010.0            103.0
# 1                  NaN                  NaN         NaN              NaN
# 2                  NaN                  NaN         NaN              NaN
# 3            Inception            Inception      2010.0            148.0
# 4  Shrek Forever After  Shrek Forever After      2010.0             93.0
#
#                        genres
# 0  Adventure,Animation,Comedy
# 1                         NaN
# 2                         NaN
# 3     Action,Adventure,Sci-Fi
# 4  Adventure,Animation,Comedy

# %%
gross_budget_basics_merge_df_copy['movie'] = gross_budget_basics_merge_df['movie'].str.replace('[.,;:\(\)]', '').str.lower()
gross_budget_basics_merge_df_copy.head()
# Out:
#                                          title studio  domestic_gross_x  \
# 0                                  toy story 3     BV       415000000.0
# 1                   alice in wonderland (2010)     BV       334200000.0
# 2  harry potter and the deathly hallows part 1     WB       296000000.0
# 3                                    inception     WB       292600000.0
# 4                          shrek forever after   P/DW       238700000.0
#
#   foreign_gross  year    id  release_date                movie  \
# 0     652000000  2010  47.0  Jun 18, 2010          toy story 3
# 1     691300000  2010   NaN           NaN                  NaN
# 2     664300000  2010   NaN           NaN                  NaN
# 3     535700000  2010  38.0  Jul 16, 2010            inception
# 4     513900000  2010  27.0  May 21, 2010  shrek forever after
#
#   production_budget domestic_gross_y worldwide_gross   movie_id  \
# 0      $200,000,000     $415,004,880  $1,068,879,522  tt0435761
# 1               NaN              NaN             NaN        NaN
# 2               NaN              NaN             NaN        NaN
# 3      $160,000,000     $292,576,195    $835,524,642  tt1375666
# 4      $165,000,000     $238,736,787    $756,244,673  tt0892791
#
#          primary_title       original_title  start_year  runtime_minutes  \
# 0          Toy Story 3          Toy Story 3      2010.0            103.0
# 1                  NaN                  NaN         NaN              NaN
# 2                  NaN                  NaN         NaN              NaN
# 3            Inception            Inception      2010.0            148.0
# 4  Shrek Forever After  Shrek Forever After      2010.0             93.0
#
#                        genres
# 0  Adventure,Animation,Comedy
# 1                         NaN
# 2                         NaN
# 3     Action,Adventure,Sci-Fi
# 4  Adventure,Animation,Comedy

# %%
gross_budget_basics_merge_df_copy['primary_title'] = gross_budget_basics_merge_df['primary_title'].str.replace('[.,;:\(\)]', '').str.lower()
gross_budget_basics_merge_df_copy.head()
# Out:
#                                          title studio  domestic_gross_x  \
# 0                                  toy story 3     BV       415000000.0
# 1                   alice in wonderland (2010)     BV       334200000.0
# 2  harry potter and the deathly hallows part 1     WB       296000000.0
# 3                                    inception     WB       292600000.0
# 4                          shrek forever after   P/DW       238700000.0
#
#   foreign_gross  year    id  release_date                movie  \
# 0     652000000  2010  47.0  Jun 18, 2010          toy story 3
# 1     691300000  2010   NaN           NaN                  NaN
# 2     664300000  2010   NaN           NaN                  NaN
# 3     535700000  2010  38.0  Jul 16, 2010            inception
# 4     513900000  2010  27.0  May 21, 2010  shrek forever after
#
#   production_budget domestic_gross_y worldwide_gross   movie_id  \
# 0      $200,000,000     $415,004,880  $1,068,879,522  tt0435761
# 1               NaN              NaN             NaN        NaN
# 2               NaN              NaN             NaN        NaN
# 3      $160,000,000     $292,576,195    $835,524,642  tt1375666
# 4      $165,000,000     $238,736,787    $756,244,673  tt0892791
#
#          primary_title       original_title  start_year  runtime_minutes  \
# 0          toy story 3          Toy Story 3      2010.0            103.0
# 1                  NaN                  NaN         NaN              NaN
# 2                  NaN                  NaN         NaN              NaN
# 3            inception            Inception      2010.0            148.0
# 4  shrek forever after  Shrek Forever After      2010.0             93.0
#
#                        genres
# 0  Adventure,Animation,Comedy
# 1                         NaN
# 2                         NaN
# 3     Action,Adventure,Sci-Fi
# 4  Adventure,Animation,Comedy

# %% [markdown]
# Clean up 'production_budget', 'domestic_gross_y', 'worldwide_gross' by removing $, make float

# %%
gross_budget_basics_merge_df_copy['production_budget'] = gross_budget_basics_merge_df['production_budget'].str.replace('[\$,]', '', regex=True).astype(float)
gross_budget_basics_merge_df_copy.head()
# Out:
#                                          title studio  domestic_gross_x  \
# 0                                  toy story 3     BV       415000000.0
# 1                   alice in wonderland (2010)     BV       334200000.0
# 2  harry potter and the deathly hallows part 1     WB       296000000.0
# 3                                    inception     WB       292600000.0
# 4                          shrek forever after   P/DW       238700000.0
#
#   foreign_gross  year    id  release_date                movie  \
# 0     652000000  2010  47.0  Jun 18, 2010          toy story 3
# 1     691300000  2010   NaN           NaN                  NaN
# 2     664300000  2010   NaN           NaN                  NaN
# 3     535700000  2010  38.0  Jul 16, 2010            inception
# 4     513900000  2010  27.0  May 21, 2010  shrek forever after
#
#    production_budget domestic_gross_y worldwide_gross   movie_id  \
# 0        200000000.0     $415,004,880  $1,068,879,522  tt0435761
# 1                NaN              NaN             NaN        NaN
# 2                NaN              NaN             NaN        NaN
# 3        160000000.0     $292,576,195    $835,524,642  tt1375666
# 4        165000000.0     $238,736,787    $756,244,673  tt0892791
#
#          primary_title       original_title  start_year  runtime_minutes  \
# 0          toy story 3          Toy Story 3      2010.0            103.0
# 1                  NaN                  NaN         NaN              NaN
# 2                  NaN                  NaN         NaN              NaN
# 3            inception            Inception      2010.0            148.0
# 4  shrek forever after  Shrek Forever After      2010.0             93.0
#
#                        genres
# 0  Adventure,Animation,Comedy
# 1                         NaN
# 2                         NaN
# 3     Action,Adventure,Sci-Fi
# 4  Adventure,Animation,Comedy

# %%
gross_budget_basics_merge_df_copy['domestic_gross_y'] = gross_budget_basics_merge_df['domestic_gross_y'].str.replace('[\$,]', '', regex=True).astype(float)
gross_budget_basics_merge_df_copy.head()
# Out:
#                                          title studio  domestic_gross_x  \
# 0                                  toy story 3     BV       415000000.0
# 1                   alice in wonderland (2010)     BV       334200000.0
# 2  harry potter and the deathly hallows part 1     WB       296000000.0
# 3                                    inception     WB       292600000.0
# 4                          shrek forever after   P/DW       238700000.0
#
#   foreign_gross  year    id  release_date                movie  \
# 0     652000000  2010  47.0  Jun 18, 2010          toy story 3
# 1     691300000  2010   NaN           NaN                  NaN
# 2     664300000  2010   NaN           NaN                  NaN
# 3     535700000  2010  38.0  Jul 16, 2010            inception
# 4     513900000  2010  27.0  May 21, 2010  shrek forever after
#
#    production_budget  domestic_gross_y worldwide_gross   movie_id  \
# 0        200000000.0       415004880.0  $1,068,879,522  tt0435761
# 1                NaN               NaN             NaN        NaN
# 2                NaN               NaN             NaN        NaN
# 3        160000000.0       292576195.0    $835,524,642  tt1375666
# 4        165000000.0       238736787.0    $756,244,673  tt0892791
#
#          primary_title       original_title  start_year  runtime_minutes  \
# 0          toy story 3          Toy Story 3      2010.0            103.0
# 1                  NaN                  NaN         NaN              NaN
# 2                  NaN                  NaN         NaN              NaN
# 3            inception            Inception      2010.0            148.0
# 4  shrek forever after  Shrek Forever After      2010.0             93.0
#
#                        genres
# 0  Adventure,Animation,Comedy
# 1                         NaN
# 2                         NaN
# 3     Action,Adventure,Sci-Fi
# 4  Adventure,Animation,Comedy

# %%
gross_budget_basics_merge_df_copy['worldwide_gross'] = gross_budget_basics_merge_df['worldwide_gross'].str.replace('[\$,]', '', regex=True).astype(float)
gross_budget_basics_merge_df_copy.head()
# Out:
#                                          title studio  domestic_gross_x  \
# 0                                  toy story 3     BV       415000000.0
# 1                   alice in wonderland (2010)     BV       334200000.0
# 2  harry potter and the deathly hallows part 1     WB       296000000.0
# 3                                    inception     WB       292600000.0
# 4                          shrek forever after   P/DW       238700000.0
#
#   foreign_gross  year    id  release_date                movie  \
# 0     652000000  2010  47.0  Jun 18, 2010          toy story 3
# 1     691300000  2010   NaN           NaN                  NaN
# 2     664300000  2010   NaN           NaN                  NaN
# 3     535700000  2010  38.0  Jul 16, 2010            inception
# 4     513900000  2010  27.0  May 21, 2010  shrek forever after
#
#    production_budget  domestic_gross_y  worldwide_gross   movie_id  \
# 0        200000000.0       415004880.0     1.068880e+09  tt0435761
# 1                NaN               NaN              NaN        NaN
# 2                NaN               NaN              NaN        NaN
# 3        160000000.0       292576195.0     8.355246e+08  tt1375666
# 4        165000000.0       238736787.0     7.562447e+08  tt0892791
#
#          primary_title       original_title  start_year  runtime_minutes  \
# 0          toy story 3          Toy Story 3      2010.0            103.0
# 1                  NaN                  NaN         NaN              NaN
# 2                  NaN                  NaN         NaN              NaN
# 3            inception            Inception      2010.0            148.0
# 4  shrek forever after  Shrek Forever After      2010.0             93.0
#
#                        genres
# 0  Adventure,Animation,Comedy
# 1                         NaN
# 2                         NaN
# 3     Action,Adventure,Sci-Fi
# 4  Adventure,Animation,Comedy

# %% [markdown]
# Double check!

# %%
gross_budget_basics_merge_df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4175 entries, 0 to 4174
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              4175 non-null   object
#  1   studio             4170 non-null   object
#  2   domestic_gross_x   4140 non-null   float64
#  3   foreign_gross      2539 non-null   object
#  4   year               4175 non-null   int64
#  5   id                 1682 non-null   float64
#  6   release_date       1682 non-null   object
#  7   movie              1682 non-null   object
#  8   production_budget  1682 non-null   float64
#  9   domestic_gross_y   1682 non-null   float64
#  10  worldwide_gross    1682 non-null   float64
#  11  movie_id           3394 non-null   object
#  12  primary_title      3394 non-null   object
#  13  original_title     3394 non-null   object
#  14  start_year         3394 non-null   float64
#  15  runtime_minutes    3222 non-null   float64
#  16  genres             3351 non-null   object
# dtypes: float64(7), int64(1), object(9)
# memory usage: 554.6+ KB

# %% [markdown]
# Calculate and add "ROI" from 'worldwide_gross' - 'production_budget' / 'production_budget' columns

# %%
gross_budget_basics_merge_df_copy['roi'] = ((gross_budget_basics_merge_df_copy['worldwide_gross'] - gross_budget_basics_merge_df_copy['production_budget']) / gross_budget_basics_merge_df_copy['production_budget'])
gross_budget_basics_merge_df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4175 entries, 0 to 4174
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              4175 non-null   object
#  1   studio             4170 non-null   object
#  2   domestic_gross_x   4140 non-null   float64
#  3   foreign_gross      2539 non-null   object
#  4   year               4175 non-null   int64
#  5   id                 1682 non-null   float64
#  6   release_date       1682 non-null   object
#  7   movie              1682 non-null   object
#  8   production_budget  1682 non-null   float64
#  9   domestic_gross_y   1682 non-null   float64
#  10  worldwide_gross    1682 non-null   float64
#  11  movie_id           3394 non-null   object
#  12  primary_title      3394 non-null   object
#  13  original_title     3394 non-null   object
#  14  start_year         3394 non-null   float64
#  15  runtime_minutes    3222 non-null   float64
#  16  genres             3351 non-null   object
#  17  roi                1682 non-null   float64
# dtypes: float64(8), int64(1), object(9)
# memory usage: 587.2+ KB

# %%
gross_budget_basics_merge_df_copy.head()
# Out:
#                                          title studio  domestic_gross_x  \
# 0                                  toy story 3     BV       415000000.0
# 1                   alice in wonderland (2010)     BV       334200000.0
# 2  harry potter and the deathly hallows part 1     WB       296000000.0
# 3                                    inception     WB       292600000.0
# 4                          shrek forever after   P/DW       238700000.0
#
#   foreign_gross  year    id  release_date                movie  \
# 0     652000000  2010  47.0  Jun 18, 2010          toy story 3
# 1     691300000  2010   NaN           NaN                  NaN
# 2     664300000  2010   NaN           NaN                  NaN
# 3     535700000  2010  38.0  Jul 16, 2010            inception
# 4     513900000  2010  27.0  May 21, 2010  shrek forever after
#
#    production_budget  domestic_gross_y  worldwide_gross   movie_id  \
# 0        200000000.0       415004880.0     1.068880e+09  tt0435761
# 1                NaN               NaN              NaN        NaN
# 2                NaN               NaN              NaN        NaN
# 3        160000000.0       292576195.0     8.355246e+08  tt1375666
# 4        165000000.0       238736787.0     7.562447e+08  tt0892791
#
#          primary_title       original_title  start_year  runtime_minutes  \
# 0          toy story 3          Toy Story 3      2010.0            103.0
# 1                  NaN                  NaN         NaN              NaN
# 2                  NaN                  NaN         NaN              NaN
# 3            inception            Inception      2010.0            148.0
# 4  shrek forever after  Shrek Forever After      2010.0             93.0
#
#                        genres       roi
# 0  Adventure,Animation,Comedy  4.344398
# 1                         NaN       NaN
# 2                         NaN       NaN
# 3     Action,Adventure,Sci-Fi  4.222029
# 4  Adventure,Animation,Comedy  3.583301

# %% [markdown]
# Add foreign_gross_y column from the worldwide_gross - domestic_gross_y

# %%
gross_budget_basics_merge_df_copy['foreign_gross_y'] = gross_budget_basics_merge_df_copy['worldwide_gross'] - gross_budget_basics_merge_df_copy['domestic_gross_y']
gross_budget_basics_merge_df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4175 entries, 0 to 4174
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              4175 non-null   object
#  1   studio             4170 non-null   object
#  2   domestic_gross_x   4140 non-null   float64
#  3   foreign_gross      2539 non-null   object
#  4   year               4175 non-null   int64
#  5   id                 1682 non-null   float64
#  6   release_date       1682 non-null   object
#  7   movie              1682 non-null   object
#  8   production_budget  1682 non-null   float64
#  9   domestic_gross_y   1682 non-null   float64
#  10  worldwide_gross    1682 non-null   float64
#  11  movie_id           3394 non-null   object
#  12  primary_title      3394 non-null   object
#  13  original_title     3394 non-null   object
#  14  start_year         3394 non-null   float64
#  15  runtime_minutes    3222 non-null   float64
#  16  genres             3351 non-null   object
#  17  roi                1682 non-null   float64
#  18  foreign_gross_y    1682 non-null   float64
# dtypes: float64(9), int64(1), object(9)
# memory usage: 619.9+ KB

# %%
gross_budget_basics_merge_df_copy.head()
# Out:
#                                          title studio  domestic_gross_x  \
# 0                                  toy story 3     BV       415000000.0
# 1                   alice in wonderland (2010)     BV       334200000.0
# 2  harry potter and the deathly hallows part 1     WB       296000000.0
# 3                                    inception     WB       292600000.0
# 4                          shrek forever after   P/DW       238700000.0
#
#   foreign_gross  year    id  release_date                movie  \
# 0     652000000  2010  47.0  Jun 18, 2010          toy story 3
# 1     691300000  2010   NaN           NaN                  NaN
# 2     664300000  2010   NaN           NaN                  NaN
# 3     535700000  2010  38.0  Jul 16, 2010            inception
# 4     513900000  2010  27.0  May 21, 2010  shrek forever after
#
#    production_budget  domestic_gross_y  worldwide_gross   movie_id  \
# 0        200000000.0       415004880.0     1.068880e+09  tt0435761
# 1                NaN               NaN              NaN        NaN
# 2                NaN               NaN              NaN        NaN
# 3        160000000.0       292576195.0     8.355246e+08  tt1375666
# 4        165000000.0       238736787.0     7.562447e+08  tt0892791
#
#          primary_title       original_title  start_year  runtime_minutes  \
# 0          toy story 3          Toy Story 3      2010.0            103.0
# 1                  NaN                  NaN         NaN              NaN
# 2                  NaN                  NaN         NaN              NaN
# 3            inception            Inception      2010.0            148.0
# 4  shrek forever after  Shrek Forever After      2010.0             93.0
#
#                        genres       roi  foreign_gross_y
# 0  Adventure,Animation,Comedy  4.344398      653874642.0
# 1                         NaN       NaN              NaN
# 2                         NaN       NaN              NaN
# 3     Action,Adventure,Sci-Fi  4.222029      542948447.0
# 4  Adventure,Animation,Comedy  3.583301      517507886.0

# %% [markdown]
# Drop columns 'original_title', 'id', 'start_year'

# %%
gross_budget_basics_merge_df_copy = gross_budget_basics_merge_df_copy.drop(columns='original_title')
gross_budget_basics_merge_df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4175 entries, 0 to 4174
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              4175 non-null   object
#  1   studio             4170 non-null   object
#  2   domestic_gross_x   4140 non-null   float64
#  3   foreign_gross      2539 non-null   object
#  4   year               4175 non-null   int64
#  5   id                 1682 non-null   float64
#  6   release_date       1682 non-null   object
#  7   movie              1682 non-null   object
#  8   production_budget  1682 non-null   float64
#  9   domestic_gross_y   1682 non-null   float64
#  10  worldwide_gross    1682 non-null   float64
#  11  movie_id           3394 non-null   object
#  12  primary_title      3394 non-null   object
#  13  start_year         3394 non-null   float64
#  14  runtime_minutes    3222 non-null   float64
#  15  genres             3351 non-null   object
#  16  roi                1682 non-null   float64
#  17  foreign_gross_y    1682 non-null   float64
# dtypes: float64(9), int64(1), object(8)
# memory usage: 587.2+ KB

# %%
gross_budget_basics_merge_df_copy = gross_budget_basics_merge_df_copy.drop(columns='id')
gross_budget_basics_merge_df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4175 entries, 0 to 4174
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              4175 non-null   object
#  1   studio             4170 non-null   object
#  2   domestic_gross_x   4140 non-null   float64
#  3   foreign_gross      2539 non-null   object
#  4   year               4175 non-null   int64
#  5   release_date       1682 non-null   object
#  6   movie              1682 non-null   object
#  7   production_budget  1682 non-null   float64
#  8   domestic_gross_y   1682 non-null   float64
#  9   worldwide_gross    1682 non-null   float64
#  10  movie_id           3394 non-null   object
#  11  primary_title      3394 non-null   object
#  12  start_year         3394 non-null   float64
#  13  runtime_minutes    3222 non-null   float64
#  14  genres             3351 non-null   object
#  15  roi                1682 non-null   float64
#  16  foreign_gross_y    1682 non-null   float64
# dtypes: float64(8), int64(1), object(8)
# memory usage: 554.6+ KB

# %%
gross_budget_basics_merge_df_copy = gross_budget_basics_merge_df_copy.drop(columns='start_year')
gross_budget_basics_merge_df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4175 entries, 0 to 4174
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              4175 non-null   object
#  1   studio             4170 non-null   object
#  2   domestic_gross_x   4140 non-null   float64
#  3   foreign_gross      2539 non-null   object
#  4   year               4175 non-null   int64
#  5   release_date       1682 non-null   object
#  6   movie              1682 non-null   object
#  7   production_budget  1682 non-null   float64
#  8   domestic_gross_y   1682 non-null   float64
#  9   worldwide_gross    1682 non-null   float64
#  10  movie_id           3394 non-null   object
#  11  primary_title      3394 non-null   object
#  12  runtime_minutes    3222 non-null   float64
#  13  genres             3351 non-null   object
#  14  roi                1682 non-null   float64
#  15  foreign_gross_y    1682 non-null   float64
# dtypes: float64(7), int64(1), object(8)
# memory usage: 522.0+ KB

# %% [markdown]
# Now to fix 'genres' column, explode after joining directors, producers, writers
# Fill NaN values with 'Missing' in 'genres'

# %%
def split_data(genre_list):
    return list(filter(None, genre_list.split(',')))

# %%
gross_budget_basics_merge_df_copy['genres'] = gross_budget_basics_merge_df_copy['genres'].fillna('Missing')
gross_budget_basics_merge_df_copy.head()
# Out:
#                                          title studio  domestic_gross_x  \
# 0                                  toy story 3     BV       415000000.0
# 1                   alice in wonderland (2010)     BV       334200000.0
# 2  harry potter and the deathly hallows part 1     WB       296000000.0
# 3                                    inception     WB       292600000.0
# 4                          shrek forever after   P/DW       238700000.0
#
#   foreign_gross  year  release_date                movie  production_budget  \
# 0     652000000  2010  Jun 18, 2010          toy story 3        200000000.0
# 1     691300000  2010           NaN                  NaN                NaN
# 2     664300000  2010           NaN                  NaN                NaN
# 3     535700000  2010  Jul 16, 2010            inception        160000000.0
# 4     513900000  2010  May 21, 2010  shrek forever after        165000000.0
#
#    domestic_gross_y  worldwide_gross   movie_id        primary_title  \
# 0       415004880.0     1.068880e+09  tt0435761          toy story 3
# 1               NaN              NaN        NaN                  NaN
# 2               NaN              NaN        NaN                  NaN
# 3       292576195.0     8.355246e+08  tt1375666            inception
# 4       238736787.0     7.562447e+08  tt0892791  shrek forever after
#
#    runtime_minutes                      genres       roi  foreign_gross_y
# 0            103.0  Adventure,Animation,Comedy  4.344398      653874642.0
# 1              NaN                     Missing       NaN              NaN
# 2              NaN                     Missing       NaN              NaN
# 3            148.0     Action,Adventure,Sci-Fi  4.222029      542948447.0
# 4             93.0  Adventure,Animation,Comedy  3.583301      517507886.0

# %%
gross_budget_basics_merge_df_copy['genre_list'] = gross_budget_basics_merge_df_copy['genres'].apply(split_data)

# %%
gross_budget_basics_merge_df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4175 entries, 0 to 4174
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              4175 non-null   object
#  1   studio             4170 non-null   object
#  2   domestic_gross_x   4140 non-null   float64
#  3   foreign_gross      2539 non-null   object
#  4   year               4175 non-null   int64
#  5   release_date       1682 non-null   object
#  6   movie              1682 non-null   object
#  7   production_budget  1682 non-null   float64
#  8   domestic_gross_y   1682 non-null   float64
#  9   worldwide_gross    1682 non-null   float64
#  10  movie_id           3394 non-null   object
#  11  primary_title      3394 non-null   object
#  12  runtime_minutes    3222 non-null   float64
#  13  genres             4175 non-null   object
#  14  roi                1682 non-null   float64
#  15  foreign_gross_y    1682 non-null   float64
#  16  genre_list         4175 non-null   object
# dtypes: float64(7), int64(1), object(9)
# memory usage: 554.6+ KB

# %%
gross_budget_basics_merge_df_copy['genre_list'] = gross_budget_basics_merge_df_copy['genres'].apply(split_data)

def split_data(genre_list):
    return genre_list.split()

gross_budget_basics_merge_df_copy['genre_list'].head()
# Out:
# 0    [Adventure, Animation, Comedy]
# 1                         [Missing]
# 2                         [Missing]
# 3       [Action, Adventure, Sci-Fi]
# 4    [Adventure, Animation, Comedy]
# Name: genre_list, dtype: object

# %%
gross_budget_basics_merge_df_copy['genres'] = gross_budget_basics_merge_df_copy['genre_list']

# %%
gross_budget_basics_merge_df_copy.drop(columns=['genre_list'], inplace=True)

# %%
gross_budget_basics_merge_df_copy.head()
# Out:
#                                          title studio  domestic_gross_x  \
# 0                                  toy story 3     BV       415000000.0
# 1                   alice in wonderland (2010)     BV       334200000.0
# 2  harry potter and the deathly hallows part 1     WB       296000000.0
# 3                                    inception     WB       292600000.0
# 4                          shrek forever after   P/DW       238700000.0
#
#   foreign_gross  year  release_date                movie  production_budget  \
# 0     652000000  2010  Jun 18, 2010          toy story 3        200000000.0
# 1     691300000  2010           NaN                  NaN                NaN
# 2     664300000  2010           NaN                  NaN                NaN
# 3     535700000  2010  Jul 16, 2010            inception        160000000.0
# 4     513900000  2010  May 21, 2010  shrek forever after        165000000.0
#
#    domestic_gross_y  worldwide_gross   movie_id        primary_title  \
# 0       415004880.0     1.068880e+09  tt0435761          toy story 3
# 1               NaN              NaN        NaN                  NaN
# 2               NaN              NaN        NaN                  NaN
# 3       292576195.0     8.355246e+08  tt1375666            inception
# 4       238736787.0     7.562447e+08  tt0892791  shrek forever after
#
#    runtime_minutes                          genres       roi  foreign_gross_y
# 0            103.0  [Adventure, Animation, Comedy]  4.344398      653874642.0
# 1              NaN                       [Missing]       NaN              NaN
# 2              NaN                       [Missing]       NaN              NaN
# 3            148.0     [Action, Adventure, Sci-Fi]  4.222029      542948447.0
# 4             93.0  [Adventure, Animation, Comedy]  3.583301      517507886.0

# %%
gross_budget_basics_merge_df_copy['genres'].head()
# Out:
# 0    [Adventure, Animation, Comedy]
# 1                         [Missing]
# 2                         [Missing]
# 3       [Action, Adventure, Sci-Fi]
# 4    [Adventure, Animation, Comedy]
# Name: genres, dtype: object

# %% [markdown]
# Now to join directors, writers, producers

# %%
imdb_directors_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 291174 entries, 0 to 291173
# Data columns (total 2 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   movie_id   291174 non-null  object
#  1   person_id  291174 non-null  object
# dtypes: object(2)
# memory usage: 4.4+ MB

# %%
imdb_movie_akas_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 331703 entries, 0 to 331702
# Data columns (total 8 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   movie_id           331703 non-null  object
#  1   ordering           331703 non-null  int64
#  2   title              331703 non-null  object
#  3   region             278410 non-null  object
#  4   language           41715 non-null   object
#  5   types              168447 non-null  object
#  6   attributes         14925 non-null   object
#  7   is_original_title  331678 non-null  float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 20.2+ MB

# %%
imdb_persons_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 606648 entries, 0 to 606647
# Data columns (total 5 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   person_id           606648 non-null  object
#  1   primary_name        606648 non-null  object
#  2   birth_year          82736 non-null   float64
#  3   death_year          6783 non-null    float64
#  4   primary_profession  555308 non-null  object
# dtypes: float64(2), object(3)
# memory usage: 23.1+ MB

# %%
imdb_principals_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1028186 entries, 0 to 1028185
# Data columns (total 6 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   movie_id    1028186 non-null  object
#  1   ordering    1028186 non-null  int64
#  2   person_id   1028186 non-null  object
#  3   category    1028186 non-null  object
#  4   job         177684 non-null   object
#  5   characters  393360 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 47.1+ MB

# %%
imdb_writers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255873 entries, 0 to 255872
# Data columns (total 2 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   movie_id   255873 non-null  object
#  1   person_id  255873 non-null  object
# dtypes: object(2)
# memory usage: 3.9+ MB

# %% [markdown]
# Merge directors & persons dataframes

# %%
imdb_dir_per_merge_df = pd.merge(imdb_directors_df, imdb_persons_df, how='left', on='person_id')
imdb_dir_per_merge_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 291174 entries, 0 to 291173
# Data columns (total 6 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   movie_id            291174 non-null  object
#  1   person_id           291174 non-null  object
#  2   primary_name        291171 non-null  object
#  3   birth_year          68608 non-null   float64
#  4   death_year          1738 non-null    float64
#  5   primary_profession  290187 non-null  object
# dtypes: float64(2), object(4)
# memory usage: 13.3+ MB

# %%
imdb_dir_per_merge_df.head()
# Out:
#     movie_id  person_id       primary_name  birth_year  death_year  \
# 0  tt0285252  nm0899854        Tony Vitale      1964.0         NaN
# 1  tt0462036  nm1940585         Bill Haley         NaN         NaN
# 2  tt0835418  nm0151540  Jay Chandrasekhar      1968.0         NaN
# 3  tt0835418  nm0151540  Jay Chandrasekhar      1968.0         NaN
# 4  tt0878654  nm0089502        Albert Pyun      1954.0         NaN
#
#          primary_profession
# 0  producer,director,writer
# 1  director,writer,producer
# 2     director,actor,writer
# 3     director,actor,writer
# 4  director,writer,producer

# %% [markdown]
# Clean 'primary_profession' column, make list. Fill NaN values with 'missing'

# %%
imdb_dir_per_merge_df['primary_profession'] = imdb_dir_per_merge_df['primary_profession'].str.replace(',', ', ')
imdb_dir_per_merge_df.head()
# Out:
#     movie_id  person_id       primary_name  birth_year  death_year  \
# 0  tt0285252  nm0899854        Tony Vitale      1964.0         NaN
# 1  tt0462036  nm1940585         Bill Haley         NaN         NaN
# 2  tt0835418  nm0151540  Jay Chandrasekhar      1968.0         NaN
# 3  tt0835418  nm0151540  Jay Chandrasekhar      1968.0         NaN
# 4  tt0878654  nm0089502        Albert Pyun      1954.0         NaN
#
#            primary_profession
# 0  producer, director, writer
# 1  director, writer, producer
# 2     director, actor, writer
# 3     director, actor, writer
# 4  director, writer, producer

# %%
imdb_dir_per_merge_df['primary_profession'] = imdb_dir_per_merge_df['primary_profession'].str.replace('_', ' ')
imdb_dir_per_merge_df.head()
# Out:
#     movie_id  person_id       primary_name  birth_year  death_year  \
# 0  tt0285252  nm0899854        Tony Vitale      1964.0         NaN
# 1  tt0462036  nm1940585         Bill Haley         NaN         NaN
# 2  tt0835418  nm0151540  Jay Chandrasekhar      1968.0         NaN
# 3  tt0835418  nm0151540  Jay Chandrasekhar      1968.0         NaN
# 4  tt0878654  nm0089502        Albert Pyun      1954.0         NaN
#
#            primary_profession
# 0  producer, director, writer
# 1  director, writer, producer
# 2     director, actor, writer
# 3     director, actor, writer
# 4  director, writer, producer

# %%
def split_data(profession_list):
    return list(filter(None, profession_list.split(',')))

# %%
imdb_dir_per_merge_df['primary_profession'].fillna('missing', inplace=True)

# %%
imdb_dir_per_merge_df['profession_list'] = imdb_dir_per_merge_df['primary_profession'].apply(split_data)

# %%
imdb_dir_per_merge_df.head()
# Out:
#     movie_id  person_id       primary_name  birth_year  death_year  \
# 0  tt0285252  nm0899854        Tony Vitale      1964.0         NaN
# 1  tt0462036  nm1940585         Bill Haley         NaN         NaN
# 2  tt0835418  nm0151540  Jay Chandrasekhar      1968.0         NaN
# 3  tt0835418  nm0151540  Jay Chandrasekhar      1968.0         NaN
# 4  tt0878654  nm0089502        Albert Pyun      1954.0         NaN
#
#            primary_profession                 profession_list
# 0  producer, director, writer  [producer,  director,  writer]
# 1  director, writer, producer  [director,  writer,  producer]
# 2     director, actor, writer     [director,  actor,  writer]
# 3     director, actor, writer     [director,  actor,  writer]
# 4  director, writer, producer  [director,  writer,  producer]

# %%
imdb_dir_per_merge_df['primary_profession'] = imdb_dir_per_merge_df['profession_list']
imdb_dir_per_merge_df.head()
# Out:
#     movie_id  person_id       primary_name  birth_year  death_year  \
# 0  tt0285252  nm0899854        Tony Vitale      1964.0         NaN
# 1  tt0462036  nm1940585         Bill Haley         NaN         NaN
# 2  tt0835418  nm0151540  Jay Chandrasekhar      1968.0         NaN
# 3  tt0835418  nm0151540  Jay Chandrasekhar      1968.0         NaN
# 4  tt0878654  nm0089502        Albert Pyun      1954.0         NaN
#
#                primary_profession                 profession_list
# 0  [producer,  director,  writer]  [producer,  director,  writer]
# 1  [director,  writer,  producer]  [director,  writer,  producer]
# 2     [director,  actor,  writer]     [director,  actor,  writer]
# 3     [director,  actor,  writer]     [director,  actor,  writer]
# 4  [director,  writer,  producer]  [director,  writer,  producer]

# %%
imdb_dir_per_merge_df.drop(columns=['profession_list'], inplace=True)
imdb_dir_per_merge_df.head()
# Out:
#     movie_id  person_id       primary_name  birth_year  death_year  \
# 0  tt0285252  nm0899854        Tony Vitale      1964.0         NaN
# 1  tt0462036  nm1940585         Bill Haley         NaN         NaN
# 2  tt0835418  nm0151540  Jay Chandrasekhar      1968.0         NaN
# 3  tt0835418  nm0151540  Jay Chandrasekhar      1968.0         NaN
# 4  tt0878654  nm0089502        Albert Pyun      1954.0         NaN
#
#                primary_profession
# 0  [producer,  director,  writer]
# 1  [director,  writer,  producer]
# 2     [director,  actor,  writer]
# 3     [director,  actor,  writer]
# 4  [director,  writer,  producer]

# %%
imdb_dir_per_merge_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 291174 entries, 0 to 291173
# Data columns (total 6 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   movie_id            291174 non-null  object
#  1   person_id           291174 non-null  object
#  2   primary_name        291171 non-null  object
#  3   birth_year          68608 non-null   float64
#  4   death_year          1738 non-null    float64
#  5   primary_profession  291174 non-null  object
# dtypes: float64(2), object(4)
# memory usage: 13.3+ MB

# %% [markdown]
# 'death_year' column, remove all dead people.

# %%
# Drop rows where 'death_year' contains any value (not NaN)
imdb_dir_per_merge_df = imdb_dir_per_merge_df.drop(imdb_dir_per_merge_df[imdb_dir_per_merge_df['death_year'].notna()].index)
imdb_dir_per_merge_df.head()
# Out:
#     movie_id  person_id       primary_name  birth_year  death_year  \
# 0  tt0285252  nm0899854        Tony Vitale      1964.0         NaN
# 1  tt0462036  nm1940585         Bill Haley         NaN         NaN
# 2  tt0835418  nm0151540  Jay Chandrasekhar      1968.0         NaN
# 3  tt0835418  nm0151540  Jay Chandrasekhar      1968.0         NaN
# 4  tt0878654  nm0089502        Albert Pyun      1954.0         NaN
#
#                primary_profession
# 0  [producer,  director,  writer]
# 1  [director,  writer,  producer]
# 2     [director,  actor,  writer]
# 3     [director,  actor,  writer]
# 4  [director,  writer,  producer]

# %%
imdb_dir_per_merge_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 289436 entries, 0 to 291173
# Data columns (total 6 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   movie_id            289436 non-null  object
#  1   person_id           289436 non-null  object
#  2   primary_name        289433 non-null  object
#  3   birth_year          67077 non-null   float64
#  4   death_year          0 non-null       float64
#  5   primary_profession  289436 non-null  object
# dtypes: float64(2), object(4)
# memory usage: 15.5+ MB

# %% [markdown]
# Merge both merged df on movie_id, then explode genre and primary_profession

# %%
gbb_imdb_merge_df = pd.merge(gross_budget_basics_merge_df_copy, imdb_dir_per_merge_df, how='left', on='movie_id')
gbb_imdb_merge_df.head()
# Out:
#                         title studio  domestic_gross_x foreign_gross  year  \
# 0                 toy story 3     BV       415000000.0     652000000  2010
# 1                 toy story 3     BV       415000000.0     652000000  2010
# 2                 toy story 3     BV       415000000.0     652000000  2010
# 3                 toy story 3     BV       415000000.0     652000000  2010
# 4  alice in wonderland (2010)     BV       334200000.0     691300000  2010
#
#    release_date        movie  production_budget  domestic_gross_y  \
# 0  Jun 18, 2010  toy story 3        200000000.0       415004880.0
# 1  Jun 18, 2010  toy story 3        200000000.0       415004880.0
# 2  Jun 18, 2010  toy story 3        200000000.0       415004880.0
# 3  Jun 18, 2010  toy story 3        200000000.0       415004880.0
# 4           NaN          NaN                NaN               NaN
#
#    worldwide_gross  ... primary_title runtime_minutes  \
# 0     1.068880e+09  ...   toy story 3           103.0
# 1     1.068880e+09  ...   toy story 3           103.0
# 2     1.068880e+09  ...   toy story 3           103.0
# 3     1.068880e+09  ...   toy story 3           103.0
# 4              NaN  ...           NaN             NaN
#
#                            genres       roi  foreign_gross_y  person_id  \
# 0  [Adventure, Animation, Comedy]  4.344398      653874642.0  nm0881279
# 1  [Adventure, Animation, Comedy]  4.344398      653874642.0  nm0881279
# 2  [Adventure, Animation, Comedy]  4.344398      653874642.0  nm0881279
# 3  [Adventure, Animation, Comedy]  4.344398      653874642.0  nm0881279
# 4                       [Missing]       NaN              NaN        NaN
#
#   primary_name birth_year  death_year  \
# 0  Lee Unkrich     1967.0         NaN
# 1  Lee Unkrich     1967.0         NaN
# 2  Lee Unkrich     1967.0         NaN
# 3  Lee Unkrich     1967.0         NaN
# 4          NaN        NaN         NaN
#
#                                 primary_profession
# 0  [editorial department,  editor,  miscellaneous]
# 1  [editorial department,  editor,  miscellaneous]
# 2  [editorial department,  editor,  miscellaneous]
# 3  [editorial department,  editor,  miscellaneous]
# 4                                              NaN
#
# [5 rows x 21 columns]

# %%
gbb_imdb_merge_df.groupby(['movie']).mean(numeric_only = True)
# Out:
#                                            domestic_gross_x    year  \
# movie
# 10 cloverfield lane                              72100000.0  2016.0
# 12 strong                                        45800000.0  2018.0
# 12 years a slave                                 56700000.0  2013.0
# 127 hours                                        18300000.0  2010.0
# 13 hours: the secret soldiers of benghazi        52900000.0  2016.0
# ...                                                     ...     ...
# youth in revolt                                  15300000.0  2010.0
# zero dark thirty                                 95700000.0  2012.0
# zookeeper                                        80400000.0  2011.0
# zoolander 2                                      28800000.0  2016.0
# zootopia                                        341300000.0  2016.0
#
#                                            production_budget  \
# movie
# 10 cloverfield lane                                5000000.0
# 12 strong                                         35000000.0
# 12 years a slave                                  20000000.0
# 127 hours                                         18000000.0
# 13 hours: the secret soldiers of benghazi         50000000.0
# ...                                                      ...
# youth in revolt                                   18000000.0
# zero dark thirty                                  52500000.0
# zookeeper                                         80000000.0
# zoolander 2                                       50000000.0
# zootopia                                         150000000.0
#
#                                            domestic_gross_y  worldwide_gross  \
# movie
# 10 cloverfield lane                              72082999.0     1.082864e+08
# 12 strong                                        45819713.0     7.111838e+07
# 12 years a slave                                 56671993.0     1.810253e+08
# 127 hours                                        18335230.0     6.021717e+07
# 13 hours: the secret soldiers of benghazi        52853219.0     6.941137e+07
# ...                                                     ...              ...
# youth in revolt                                  15285588.0     1.968559e+07
# zero dark thirty                                 95720716.0     1.346124e+08
# zookeeper                                        80360866.0     1.708055e+08
# zoolander 2                                      28848693.0     5.534869e+07
# zootopia                                        341268248.0     1.019430e+09
#
#                                            runtime_minutes        roi  \
# movie
# 10 cloverfield lane                                  103.0  20.657284
# 12 strong                                            130.0   1.031954
# 12 years a slave                                     134.0   8.051267
# 127 hours                                             94.0   2.345398
# 13 hours: the secret soldiers of benghazi              NaN   0.388227
# ...                                                    ...        ...
# youth in revolt                                        NaN   0.093644
# zero dark thirty                                     157.0   1.564046
# zookeeper                                            102.0   1.135069
# zoolander 2                                          101.0   0.106974
# zootopia                                             108.0   5.796197
#
#                                            foreign_gross_y   birth_year  \
# movie
# 10 cloverfield lane                             36203423.0          NaN
# 12 strong                                       25298665.0  1972.000000
# 12 years a slave                               124353350.0  1969.000000
# 127 hours                                       41881941.0  1956.000000
# 13 hours: the secret soldiers of benghazi       16558151.0          NaN
# ...                                                    ...          ...
# youth in revolt                                  4400000.0          NaN
# zero dark thirty                                38891719.0  1951.000000
# zookeeper                                       90444659.0  1966.000000
# zoolander 2                                     26500000.0  1965.000000
# zootopia                                       678161368.0  1968.333333
#
#                                            death_year
# movie
# 10 cloverfield lane                               NaN
# 12 strong                                         NaN
# 12 years a slave                                  NaN
# 127 hours                                         NaN
# 13 hours: the secret soldiers of benghazi         NaN
# ...                                               ...
# youth in revolt                                   NaN
# zero dark thirty                                  NaN
# zookeeper                                         NaN
# zoolander 2                                       NaN
# zootopia                                          NaN
#
# [1238 rows x 10 columns]

# %%
gbb_imdb_merge_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9961 entries, 0 to 9960
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   title               9961 non-null   object
#  1   studio              9954 non-null   object
#  2   domestic_gross_x    9897 non-null   float64
#  3   foreign_gross       6466 non-null   object
#  4   year                9961 non-null   int64
#  5   release_date        4670 non-null   object
#  6   movie               4670 non-null   object
#  7   production_budget   4670 non-null   float64
#  8   domestic_gross_y    4670 non-null   float64
#  9   worldwide_gross     4670 non-null   float64
#  10  movie_id            9180 non-null   object
#  11  primary_title       9180 non-null   object
#  12  runtime_minutes     8783 non-null   float64
#  13  genres              9961 non-null   object
#  14  roi                 4670 non-null   float64
#  15  foreign_gross_y     4670 non-null   float64
#  16  person_id           9099 non-null   object
#  17  primary_name        9099 non-null   object
#  18  birth_year          5538 non-null   float64
#  19  death_year          0 non-null      float64
#  20  primary_profession  9099 non-null   object
# dtypes: float64(9), int64(1), object(11)
# memory usage: 1.6+ MB

# %%
drop_dup_df = gbb_imdb_merge_df.drop_duplicates(subset=['movie'])
drop_dup_df.head()
# Out:
#                          title studio  domestic_gross_x foreign_gross  year  \
# 0                  toy story 3     BV       415000000.0     652000000  2010
# 4   alice in wonderland (2010)     BV       334200000.0     691300000  2010
# 6                    inception     WB       292600000.0     535700000  2010
# 7          shrek forever after   P/DW       238700000.0     513900000  2010
# 17  the twilight saga: eclipse   Sum.       300500000.0     398000000  2010
#
#     release_date                       movie  production_budget  \
# 0   Jun 18, 2010                 toy story 3        200000000.0
# 4            NaN                         NaN                NaN
# 6   Jul 16, 2010                   inception        160000000.0
# 7   May 21, 2010         shrek forever after        165000000.0
# 17  Jun 30, 2010  the twilight saga: eclipse         68000000.0
#
#     domestic_gross_y  worldwide_gross  ...               primary_title  \
# 0        415004880.0     1.068880e+09  ...                 toy story 3
# 4                NaN              NaN  ...                         NaN
# 6        292576195.0     8.355246e+08  ...                   inception
# 7        238736787.0     7.562447e+08  ...         shrek forever after
# 17       300531751.0     7.061028e+08  ...  the twilight saga: eclipse
#
#    runtime_minutes                          genres       roi  foreign_gross_y  \
# 0            103.0  [Adventure, Animation, Comedy]  4.344398      653874642.0
# 4              NaN                       [Missing]       NaN              NaN
# 6            148.0     [Action, Adventure, Sci-Fi]  4.222029      542948447.0
# 7             93.0  [Adventure, Animation, Comedy]  3.583301      517507886.0
# 17           124.0     [Adventure, Drama, Fantasy]  9.383865      405571077.0
#
#     person_id       primary_name birth_year  death_year  \
# 0   nm0881279        Lee Unkrich     1967.0         NaN
# 4         NaN                NaN        NaN         NaN
# 6   nm0634240  Christopher Nolan     1970.0         NaN
# 7   nm0593610      Mike Mitchell        NaN         NaN
# 17  nm1720541        David Slade     1969.0         NaN
#
#                                  primary_profession
# 0   [editorial department,  editor,  miscellaneous]
# 4                                               NaN
# 6                    [writer,  producer,  director]
# 7                       [actor,  director,  writer]
# 17                   [producer,  director,  writer]
#
# [5 rows x 21 columns]

# %%
drop_dup_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1239 entries, 0 to 9727
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   title               1239 non-null   object
#  1   studio              1238 non-null   object
#  2   domestic_gross_x    1237 non-null   float64
#  3   foreign_gross       1080 non-null   object
#  4   year                1239 non-null   int64
#  5   release_date        1238 non-null   object
#  6   movie               1238 non-null   object
#  7   production_budget   1238 non-null   float64
#  8   domestic_gross_y    1238 non-null   float64
#  9   worldwide_gross     1238 non-null   float64
#  10  movie_id            1158 non-null   object
#  11  primary_title       1158 non-null   object
#  12  runtime_minutes     1139 non-null   float64
#  13  genres              1239 non-null   object
#  14  roi                 1238 non-null   float64
#  15  foreign_gross_y     1238 non-null   float64
#  16  person_id           1140 non-null   object
#  17  primary_name        1140 non-null   object
#  18  birth_year          864 non-null    float64
#  19  death_year          0 non-null      float64
#  20  primary_profession  1140 non-null   object
# dtypes: float64(9), int64(1), object(11)
# memory usage: 213.0+ KB

# %% [markdown]
# round domestic_gross_y, worldwide_gross, foreign_gross_y

# %%
columns_to_round = ['domestic_gross_y', 'worldwide_gross', 'foreign_gross_y']
drop_dup_df[columns_to_round] = drop_dup_df[columns_to_round].round(-4)
drop_dup_df.head()
# Out:
# <ipython-input-69-450a40947549>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   drop_dup_df[columns_to_round] = drop_dup_df[columns_to_round].round(-4)
#                          title studio  domestic_gross_x foreign_gross  year  \
# 0                  toy story 3     BV       415000000.0     652000000  2010
# 4   alice in wonderland (2010)     BV       334200000.0     691300000  2010
# 6                    inception     WB       292600000.0     535700000  2010
# 7          shrek forever after   P/DW       238700000.0     513900000  2010
# 17  the twilight saga: eclipse   Sum.       300500000.0     398000000  2010
#
#     release_date                       movie  production_budget  \
# 0   Jun 18, 2010                 toy story 3        200000000.0
# 4            NaN                         NaN                NaN
# 6   Jul 16, 2010                   inception        160000000.0
# 7   May 21, 2010         shrek forever after        165000000.0
# 17  Jun 30, 2010  the twilight saga: eclipse         68000000.0
#
#     domestic_gross_y  worldwide_gross  ...               primary_title  \
# 0        415000000.0     1.068880e+09  ...                 toy story 3
# 4                NaN              NaN  ...                         NaN
# 6        292580000.0     8.355200e+08  ...                   inception
# 7        238740000.0     7.562400e+08  ...         shrek forever after
# 17       300530000.0     7.061000e+08  ...  the twilight saga: eclipse
#
#    runtime_minutes                          genres       roi  foreign_gross_y  \
# 0            103.0  [Adventure, Animation, Comedy]  4.344398      653870000.0
# 4              NaN                       [Missing]       NaN              NaN
# 6            148.0     [Action, Adventure, Sci-Fi]  4.222029      542950000.0
# 7             93.0  [Adventure, Animation, Comedy]  3.583301      517510000.0
# 17           124.0     [Adventure, Drama, Fantasy]  9.383865      405570000.0
#
#     person_id       primary_name birth_year  death_year  \
# 0   nm0881279        Lee Unkrich     1967.0         NaN
# 4         NaN                NaN        NaN         NaN
# 6   nm0634240  Christopher Nolan     1970.0         NaN
# 7   nm0593610      Mike Mitchell        NaN         NaN
# 17  nm1720541        David Slade     1969.0         NaN
#
#                                  primary_profession
# 0   [editorial department,  editor,  miscellaneous]
# 4                                               NaN
# 6                    [writer,  producer,  director]
# 7                       [actor,  director,  writer]
# 17                   [producer,  director,  writer]
#
# [5 rows x 21 columns]

# %% [markdown]
# recalculate roi to match updated columns

# %%
drop_dup_df['roi'] = (drop_dup_df['worldwide_gross'] - drop_dup_df['production_budget']) / drop_dup_df['production_budget']
drop_dup_df.head()
# Out:
# <ipython-input-70-e6e3541da79c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   drop_dup_df['roi'] = (drop_dup_df['worldwide_gross'] - drop_dup_df['production_budget']) / drop_dup_df['production_budget']
#                          title studio  domestic_gross_x foreign_gross  year  \
# 0                  toy story 3     BV       415000000.0     652000000  2010
# 4   alice in wonderland (2010)     BV       334200000.0     691300000  2010
# 6                    inception     WB       292600000.0     535700000  2010
# 7          shrek forever after   P/DW       238700000.0     513900000  2010
# 17  the twilight saga: eclipse   Sum.       300500000.0     398000000  2010
#
#     release_date                       movie  production_budget  \
# 0   Jun 18, 2010                 toy story 3        200000000.0
# 4            NaN                         NaN                NaN
# 6   Jul 16, 2010                   inception        160000000.0
# 7   May 21, 2010         shrek forever after        165000000.0
# 17  Jun 30, 2010  the twilight saga: eclipse         68000000.0
#
#     domestic_gross_y  worldwide_gross  ...               primary_title  \
# 0        415000000.0     1.068880e+09  ...                 toy story 3
# 4                NaN              NaN  ...                         NaN
# 6        292580000.0     8.355200e+08  ...                   inception
# 7        238740000.0     7.562400e+08  ...         shrek forever after
# 17       300530000.0     7.061000e+08  ...  the twilight saga: eclipse
#
#    runtime_minutes                          genres       roi  foreign_gross_y  \
# 0            103.0  [Adventure, Animation, Comedy]  4.344400      653870000.0
# 4              NaN                       [Missing]       NaN              NaN
# 6            148.0     [Action, Adventure, Sci-Fi]  4.222000      542950000.0
# 7             93.0  [Adventure, Animation, Comedy]  3.583273      517510000.0
# 17           124.0     [Adventure, Drama, Fantasy]  9.383824      405570000.0
#
#     person_id       primary_name birth_year  death_year  \
# 0   nm0881279        Lee Unkrich     1967.0         NaN
# 4         NaN                NaN        NaN         NaN
# 6   nm0634240  Christopher Nolan     1970.0         NaN
# 7   nm0593610      Mike Mitchell        NaN         NaN
# 17  nm1720541        David Slade     1969.0         NaN
#
#                                  primary_profession
# 0   [editorial department,  editor,  miscellaneous]
# 4                                               NaN
# 6                    [writer,  producer,  director]
# 7                       [actor,  director,  writer]
# 17                   [producer,  director,  writer]
#
# [5 rows x 21 columns]

# %% [markdown]
# Explode genres & primary profession, separate dataframes.

# %%
drop_dup_df_genre = drop_dup_df.explode('genres')
drop_dup_df_genre.genres.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='genres'>

# %%
drop_dup_df_genre.head()
# Out:
#                         title studio  domestic_gross_x foreign_gross  year  \
# 0                 toy story 3     BV       415000000.0     652000000  2010
# 0                 toy story 3     BV       415000000.0     652000000  2010
# 0                 toy story 3     BV       415000000.0     652000000  2010
# 4  alice in wonderland (2010)     BV       334200000.0     691300000  2010
# 6                   inception     WB       292600000.0     535700000  2010
#
#    release_date        movie  production_budget  domestic_gross_y  \
# 0  Jun 18, 2010  toy story 3        200000000.0       415000000.0
# 0  Jun 18, 2010  toy story 3        200000000.0       415000000.0
# 0  Jun 18, 2010  toy story 3        200000000.0       415000000.0
# 4           NaN          NaN                NaN               NaN
# 6  Jul 16, 2010    inception        160000000.0       292580000.0
#
#    worldwide_gross  ... primary_title runtime_minutes     genres     roi  \
# 0     1.068880e+09  ...   toy story 3           103.0  Adventure  4.3444
# 0     1.068880e+09  ...   toy story 3           103.0  Animation  4.3444
# 0     1.068880e+09  ...   toy story 3           103.0     Comedy  4.3444
# 4              NaN  ...           NaN             NaN    Missing     NaN
# 6     8.355200e+08  ...     inception           148.0     Action  4.2220
#
#    foreign_gross_y  person_id       primary_name birth_year  death_year  \
# 0      653870000.0  nm0881279        Lee Unkrich     1967.0         NaN
# 0      653870000.0  nm0881279        Lee Unkrich     1967.0         NaN
# 0      653870000.0  nm0881279        Lee Unkrich     1967.0         NaN
# 4              NaN        NaN                NaN        NaN         NaN
# 6      542950000.0  nm0634240  Christopher Nolan     1970.0         NaN
#
#                                 primary_profession
# 0  [editorial department,  editor,  miscellaneous]
# 0  [editorial department,  editor,  miscellaneous]
# 0  [editorial department,  editor,  miscellaneous]
# 4                                              NaN
# 6                   [writer,  producer,  director]
#
# [5 rows x 21 columns]

# %%
drop_dup_df_ex_prof = drop_dup_df.explode('primary_profession')
drop_dup_df_ex_prof.head()
# Out:
#                         title studio  domestic_gross_x foreign_gross  year  \
# 0                 toy story 3     BV       415000000.0     652000000  2010
# 0                 toy story 3     BV       415000000.0     652000000  2010
# 0                 toy story 3     BV       415000000.0     652000000  2010
# 4  alice in wonderland (2010)     BV       334200000.0     691300000  2010
# 6                   inception     WB       292600000.0     535700000  2010
#
#    release_date        movie  production_budget  domestic_gross_y  \
# 0  Jun 18, 2010  toy story 3        200000000.0       415000000.0
# 0  Jun 18, 2010  toy story 3        200000000.0       415000000.0
# 0  Jun 18, 2010  toy story 3        200000000.0       415000000.0
# 4           NaN          NaN                NaN               NaN
# 6  Jul 16, 2010    inception        160000000.0       292580000.0
#
#    worldwide_gross  ... primary_title runtime_minutes  \
# 0     1.068880e+09  ...   toy story 3           103.0
# 0     1.068880e+09  ...   toy story 3           103.0
# 0     1.068880e+09  ...   toy story 3           103.0
# 4              NaN  ...           NaN             NaN
# 6     8.355200e+08  ...     inception           148.0
#
#                            genres     roi  foreign_gross_y  person_id  \
# 0  [Adventure, Animation, Comedy]  4.3444      653870000.0  nm0881279
# 0  [Adventure, Animation, Comedy]  4.3444      653870000.0  nm0881279
# 0  [Adventure, Animation, Comedy]  4.3444      653870000.0  nm0881279
# 4                       [Missing]     NaN              NaN        NaN
# 6     [Action, Adventure, Sci-Fi]  4.2220      542950000.0  nm0634240
#
#         primary_name birth_year  death_year    primary_profession
# 0        Lee Unkrich     1967.0         NaN  editorial department
# 0        Lee Unkrich     1967.0         NaN                editor
# 0        Lee Unkrich     1967.0         NaN         miscellaneous
# 4                NaN        NaN         NaN                   NaN
# 6  Christopher Nolan     1970.0         NaN                writer
#
# [5 rows x 21 columns]

# %%
sns.pairplot(drop_dup_df_ex_prof.reset_index(), vars = ['production_budget', 'roi', 'worldwide_gross',])

# %%
top_roi_films = drop_dup_df.nlargest(30, 'roi')
print("Top ROI Films:")
print(top_roi_films[['title', 'genres', 'roi']])
# Out:
# Top ROI Films:
#                       title                       genres         roi
# 5969            the gallows  [Horror, Mystery, Thriller]  415.600000
# 2382       the devil inside                     [Horror]  100.760000
# 1261              insidious  [Horror, Mystery, Thriller]   65.580000
# 5896             unfriended  [Horror, Mystery, Thriller]   63.360000
# 148   paranormal activity 2                     [Horror]   58.170000
# 8301                  split     [Comedy, Romance, Sport]   54.792000
# 8310                get out  [Horror, Mystery, Thriller]   50.074000
# 2470      chernobyl diaries  [Horror, Mystery, Thriller]   41.410000
# 1111  paranormal activity 3  [Horror, Mystery, Thriller]   40.408000
# 4690              annabelle  [Horror, Mystery, Thriller]   38.516923
# 279       the last exorcism    [Drama, Horror, Thriller]   37.983333
# 3480    insidious chapter 2                    [Missing]   31.384000
# 6923                 dangal   [Action, Biography, Drama]   30.015789
# 3559              the purge           [Horror, Thriller]   29.423333
# 7008             lights out                      [Drama]   28.762000
# 2411               sinister  [Horror, Mystery, Thriller]   28.243333
# 2322  paranormal activity 4  [Horror, Mystery, Thriller]   27.564000
# 8787          a ghost story    [Drama, Fantasy, Romance]   26.700000
# 9343          truth or dare  [Horror, Romance, Thriller]   26.180000
# 3992            you're next     [Action, Comedy, Horror]   25.890000
# 2859   your sister's sister              [Comedy, Drama]   24.750000
# 63               black swan            [Drama, Thriller]   24.482308
# 8390        happy death day  [Horror, Mystery, Thriller]   24.002000
# 5890               war room                      [Drama]   23.660000
# 2301             magic mike              [Comedy, Drama]   23.364286
# 3623        a haunted house            [Comedy, Fantasy]   22.968000
# 7066    10 cloverfield lane     [Drama, Horror, Mystery]   20.658000
# 6868             la la land       [Comedy, Drama, Music]   20.317500
# 4816                  ouija  [Horror, Mystery, Thriller]   19.660000
# 8288    annabelle: creation  [Horror, Mystery, Thriller]   19.358667

# %%
top_roi_per_genre = drop_dup_df_genre.groupby('genres').apply(lambda group: group.nlargest(1, 'roi'))
print("Top ROI Films per Genre:")
print(top_roi_per_genre[['title', 'genres', 'roi']])
# Out:
# Top ROI Films per Genre:
#                                     title       genres         roi
# genres
# Action      6923                   dangal       Action   30.015789
# Adventure   5609                  minions    Adventure   14.680270
# Animation   5609                  minions    Animation   14.680270
# Biography   6923                   dangal    Biography   30.015789
# Comedy      8301                    split       Comedy   54.792000
# Crime       9565     unfriended: dark web        Crime   15.430000
# Documentary 9232            a quiet place  Documentary   18.677647
# Drama       279         the last exorcism        Drama   37.983333
# Family      8289                   wonder       Family   14.230000
# Fantasy     8787            a ghost story      Fantasy   26.700000
# History     6946           hidden figures      History    8.270800
# Horror      5969              the gallows       Horror  415.600000
# Missing     3480      insidious chapter 2      Missing   31.384000
# Music       6868               la la land        Music   20.317500
# Musical     4119  yeh jawaani hai deewani      Musical    5.124096
# Mystery     5969              the gallows      Mystery  415.600000
# Romance     8301                    split      Romance   54.792000
# Sci-Fi      4798       the purge: anarchy       Sci-Fi   11.392222
# Sport       8301                    split        Sport   54.792000
# Thriller    5969              the gallows     Thriller  415.600000
# War         199                 dear john          War    4.681200
# Western     109                 true grit      Western    6.208000

# %% [markdown]
# ROI stats per genre. group by genres.

# %%
roi_stats_per_genre = drop_dup_df_genre.groupby('genres')['roi'].agg(['mean', 'median', 'count'])
print("Mean and Median ROI per Genre:")
print(roi_stats_per_genre)
# Out:
# Mean and Median ROI per Genre:
#                   mean    median  count
# genres
# Action        2.059696  1.380208    338
# Adventure     2.355276  1.779072    282
# Animation     2.847307  1.999212     85
# Biography     2.755535  1.199250    110
# Comedy        2.788895  1.624211    415
# Crime         1.435293  0.994500    174
# Documentary   2.902122  1.725000     21
# Drama         2.558971  1.172500    583
# Family        1.728156  1.071607     71
# Fantasy       2.229681  1.097200     95
# History       1.734387  0.961833     36
# Horror       12.555034  2.856292    118
# Missing       1.922822  0.727750     86
# Music         3.024874  1.286861     36
# Musical       2.311383  2.124789      4
# Mystery      11.973393  2.790000     95
# Romance       3.372149  1.576348    160
# Sci-Fi        3.021655  2.185185    101
# Sport         4.021373  0.745250     21
# Thriller      7.206585  1.787300    193
# War           0.715582  0.134250     10
# Western       0.840779 -0.275625      8

# %% [markdown]
# Look at mean, median of production budget by genre & domestic gross

# %%
production_budget_stats_per_genre = drop_dup_df_genre.groupby('genres')['production_budget'].agg(['mean', 'median', 'count'])
domestic_gross_stats_per_genre = drop_dup_df_genre.groupby('genres')['domestic_gross_y'].agg(['mean', 'median', 'count'])

print("Mean and Median Production Budget by Genre:")
print(production_budget_stats_per_genre)

print("\nMean and Median Domestic Gross by Genre:")
print(domestic_gross_stats_per_genre)
# Out:
# Mean and Median Production Budget by Genre:
#                      mean       median  count
# genres
# Action       8.736893e+07   60000000.0    338
# Adventure    1.105670e+08  106500000.0    282
# Animation    1.020059e+08   90000000.0     85
# Biography    2.623427e+07   20000000.0    110
# Comedy       4.254342e+07   29000000.0    415
# Crime        3.405299e+07   28500000.0    174
# Documentary  1.178095e+07    5000000.0     21
# Drama        2.812718e+07   18000000.0    583
# Family       6.513239e+07   40000000.0     71
# Fantasy      8.740105e+07   60000000.0     95
# History      3.635833e+07   25000000.0     36
# Horror       2.075381e+07   10000000.0    118
# Missing      2.607279e+07   13500000.0     86
# Music        1.957500e+07   17250000.0     36
# Musical      5.432500e+07   62500000.0      4
# Mystery      2.658768e+07   10000000.0     95
# Romance      2.161734e+07   17000000.0    160
# Sci-Fi       9.988978e+07   80000000.0    101
# Sport        3.209524e+07   25000000.0     21
# Thriller     3.851937e+07   25000000.0    193
# War          2.360000e+07   19500000.0     10
# Western      6.243750e+07   30000000.0      8
#
# Mean and Median Domestic Gross by Genre:
#                      mean       median  count
# genres
# Action       9.936328e+07   53355000.0    338
# Adventure    1.315097e+08   86150000.0    282
# Animation    1.391101e+08  115230000.0     85
# Biography    4.172718e+07   20485000.0    110
# Comedy       6.404549e+07   42470000.0    415
# Crime        4.210178e+07   23795000.0    174
# Documentary  2.806619e+07    6100000.0     21
# Drama        3.617467e+07   19070000.0    583
# Family       6.863690e+07   52700000.0     71
# Fantasy      7.684705e+07   37660000.0     95
# History      4.458222e+07   23295000.0     36
# Horror       3.726500e+07   27270000.0    118
# Missing      2.800198e+07   12550000.0     86
# Music        3.945944e+07   22775000.0     36
# Musical      6.403250e+07   38980000.0      4
# Mystery      4.391421e+07   27740000.0     95
# Romance      3.378150e+07   21420000.0    160
# Sci-Fi       1.384842e+08   81700000.0    101
# Sport        5.909619e+07   35760000.0     21
# Thriller     5.275259e+07   32460000.0    193
# War          2.122000e+07    5345000.0     10
# Western      5.426750e+07    4050000.0      8

# %%
# Set the size of the plot
plt.figure(figsize=(12, 8))

# Create a boxplot with rotated x-axis labels
sns.boxplot(x='genres', y='production_budget', data=drop_dup_df_genre.reset_index())
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability

# Add labels and title
plt.xlabel('Genres')
plt.ylabel('Production Budget')
plt.title('Boxplot of Production Budget by Genre')

# show plot
plt.show()

# %%
top_genres = drop_dup_df_genre['genres'].value_counts().nlargest(10).index
filtered_df = drop_dup_df_genre[drop_dup_df_genre['genres'].isin(top_genres)]
plt.figure(figsize=(12,8))
sns.boxplot(x='genres', y='production_budget', data=drop_dup_df_genre.reset_index())
plt.xticks(rotation=45, ha='right')
plt.title('Boxplot of Production Budget by Genre')
plt.show()

# %%
# Using drop_dup_df_genre DataFrame
top_genres = drop_dup_df_genre['genres'].value_counts().nlargest(10).index
filtered_df = drop_dup_df_genre[drop_dup_df_genre['genres'].isin(top_genres)]
filtered_df = filtered_df.sort_values(by=['genres', 'production_budget'], ascending=[True, False])

# Create a violin plot with custom y-tick labels
plt.figure(figsize=(12, 8))
sns.violinplot(x='genres', y='production_budget', data=filtered_df.reset_index(), inner='quartile')
plt.xticks(rotation=45, ha='right')
plt.title('Violin Plot of Production Budget by Genre')

# Set custom y-tick labels
tick_labels = ['${:,.0f}'.format(label) for label in plt.yticks()[0]]
plt.yticks(plt.yticks()[0], tick_labels)

plt.show()

# %%
# Set the genres and filter the DataFrame
top_genres = drop_dup_df_genre['genres'].value_counts().nlargest(10).index
filtered_df = drop_dup_df_genre[drop_dup_df_genre['genres'].isin(top_genres)]
filtered_df = filtered_df.sort_values(by=['genres', 'production_budget'], ascending=[True, False])

# Set the size of the plot
plt.figure(figsize=(12, 8))

# Create a boxplot with rotated x-axis labels
sns.boxplot(x='genres', y='production_budget', data=filtered_df.reset_index(), whis=2)

# Rotate x-axis labels
plt.xticks(rotation=45, ha='right')

# Set y-axis labels as currency format
tick_labels = ['${:,.0f}'.format(label) for label in plt.yticks()[0]]
plt.yticks(plt.yticks()[0], tick_labels)

# Set plot title
plt.title('Boxplot of Production Budget by Genre')

# Show the plot
plt.show()

# %%
top_genres = drop_dup_df_genre['genres'].value_counts().nlargest(10).index
filtered_df = drop_dup_df_genre[drop_dup_df_genre['genres'].isin(top_genres)]
filtered_df = filtered_df.sort_values(by=['genres', 'domestic_gross_y'], ascending=[True, False])
plt.figure(figsize=(12,8))
sns.boxplot(x='genres', y='domestic_gross_y', data=filtered_df.reset_index())
plt.xticks(rotation=45, ha='right')
plt.title('Boxplot of Domestic Gross by Genre')
tick_labels = ['${:,.0f}'.format(label) for label in plt.yticks()[0]]
plt.yticks(plt.yticks()[0], tick_labels)
plt.show()

# %%
top_genres = drop_dup_df_genre['genres'].value_counts().nlargest(10).index
filtered_df = drop_dup_df_genre[drop_dup_df_genre['genres'].isin(top_genres)]
filtered_df = filtered_df.sort_values(by=['genres', 'worldwide_gross'], ascending=[True, False])
plt.figure(figsize=(12,8))
sns.boxplot(x='genres', y='worldwide_gross', data=filtered_df.reset_index())
plt.xticks(rotation=45, ha='right')
plt.title('Boxplot of Worldwide Gross by Genre')
tick_labels = ['${:,.0f}'.format(label) for label in plt.yticks()[0]]
plt.yticks(plt.yticks()[0], tick_labels)
plt.show()

# %%
# Using drop_dup_df_genre DataFrame
top_genres = drop_dup_df_genre['genres'].value_counts().nlargest(10).index
filtered_df = drop_dup_df_genre[drop_dup_df_genre['genres'].isin(top_genres)]
filtered_df = filtered_df.sort_values(by=['genres', 'domestic_gross_y'], ascending=[True, False])

# Create a violin plot with custom y-tick labels
plt.figure(figsize=(12, 8))
sns.violinplot(x='genres', y='domestic_gross_y', data=filtered_df.reset_index(), inner='quartile')
plt.xticks(rotation=45, ha='right')
plt.title('Violin Plot of Domestic Gross by Genre')

# Set custom y-tick labels
tick_labels = ['${:,.0f}'.format(label) for label in plt.yticks()[0]]
plt.yticks(plt.yticks()[0], tick_labels)

plt.show()

# %%
# Using drop_dup_df_genre DataFrame
top_genres = drop_dup_df_genre['genres'].value_counts().nlargest(10).index
filtered_df = drop_dup_df_genre[drop_dup_df_genre['genres'].isin(top_genres)]
filtered_df = filtered_df.sort_values(by=['genres', 'worldwide_gross'], ascending=[True, False])

# Create a violin plot with custom y-tick labels
plt.figure(figsize=(12, 8))
sns.violinplot(x='genres', y='worldwide_gross', data=filtered_df.reset_index(), inner='quartile')
plt.xticks(rotation=45, ha='right')
plt.title('Violin Plot of Worldwide Gross by Genre')

# Set custom y-tick labels
tick_labels = ['${:,.0f}'.format(label) for label in plt.yticks()[0]]
plt.yticks(plt.yticks()[0], tick_labels)

plt.show()

# %%
# Using have drop_dup_df_genre DataFrame
top_genres = drop_dup_df_genre['genres'].value_counts().nlargest(10).index
filtered_df = drop_dup_df_genre[drop_dup_df_genre['genres'].isin(top_genres)]
filtered_df = filtered_df.sort_values(by=['genres', 'production_budget'], ascending=[True, False])

# Create a violin plot with custom y-tick labels
plt.figure(figsize=(12, 8))
sns.barplot(x='genres', y='production_budget', data=filtered_df.reset_index())
plt.xticks(rotation=45, ha='right')
plt.title('Bar Plot of Production Budget by Genre')

# Set custom y-tick labels
tick_labels = ['${:,.0f}'.format(label) for label in plt.yticks()[0]]
plt.yticks(plt.yticks()[0], tick_labels)

plt.show()

# %%
# Using drop_dup_df_genre DataFrame
top_genres = drop_dup_df_genre['genres'].value_counts().nlargest(10).index
filtered_df = drop_dup_df_genre[drop_dup_df_genre['genres'].isin(top_genres)]
filtered_df = filtered_df.sort_values(by=['genres', 'domestic_gross_y'], ascending=[True, False])

# Create a violin plot with custom y-tick labels
plt.figure(figsize=(12, 8))
sns.barplot(x='genres', y='domestic_gross_y', data=filtered_df.reset_index())
plt.xticks(rotation=45, ha='right')
plt.title('Bar Plot of Domestic Gross by Genre')

# Set custom y-tick labels
tick_labels = ['${:,.0f}'.format(label) for label in plt.yticks()[0]]
plt.yticks(plt.yticks()[0], tick_labels)

plt.show()

# %%
# Using have drop_dup_df_genre DataFrame
top_genres = drop_dup_df_genre['genres'].value_counts().nlargest(10).index
filtered_df = drop_dup_df_genre[drop_dup_df_genre['genres'].isin(top_genres)]
filtered_df = filtered_df.sort_values(by=['genres', 'worldwide_gross'], ascending=[True, False])

# Create a violin plot with custom y-tick labels
plt.figure(figsize=(12, 8))
sns.barplot(x='genres', y='worldwide_gross', data=filtered_df.reset_index())
plt.xticks(rotation=45, ha='right')
plt.title('Bar Plot of Worldwide Gross by Genre')

# Set custom y-tick labels
tick_labels = ['${:,.0f}'.format(label) for label in plt.yticks()[0]]
plt.yticks(plt.yticks()[0], tick_labels)

plt.show()

# %%
# Exclude the 'Missing' genre from the DataFrame
roi_stats_per_genre = roi_stats_per_genre[roi_stats_per_genre.index != 'Missing']

# Sort the DataFrame by the mean value in descending order and take the top ten
top_ten_mean_roi = roi_stats_per_genre.sort_values(by='mean', ascending=False).head(10)

# Print the result
print("Top Ten Mean ROI per Genre:")
print(top_ten_mean_roi)
# Out:
# Top Ten Mean ROI per Genre:
#                   mean    median  count
# genres
# Horror       12.555034  2.856292    118
# Mystery      11.973393  2.790000     95
# Thriller      7.206585  1.787300    193
# Sport         4.021373  0.745250     21
# Romance       3.372149  1.576348    160
# Music         3.024874  1.286861     36
# Sci-Fi        3.021655  2.185185    101
# Documentary   2.902122  1.725000     21
# Animation     2.847307  1.999212     85
# Comedy        2.788895  1.624211    415

# %%
# Function to create a bar plot with a colormap
def create_bar_plot(data, ylabel, title):
    plt.figure(figsize=(12, 8))
    
    # Extracting values and genres
    values = data['mean']
    genres = data.index

    # Sorting values in descending order
    data_sorted = data.sort_values(by='mean', ascending=False)
    
    # Creating a colormap
    colors = plt.cm.viridis(np.linspace(0, 1, len(values)))

    # Plotting the bar chart
    bars = plt.bar(data_sorted.index, data_sorted['mean'], color=colors)

    # Adding a colorbar for reference
    cbar = plt.colorbar(plt.cm.ScalarMappable(cmap=plt.cm.viridis))
    cbar.set_label('Scale')

    # Adding labels and title
    plt.title(title)
    plt.xlabel('Genre')
    plt.ylabel(ylabel)
    plt.xticks(rotation=45, ha='right')

    # Adding value annotations on top of each bar with adjusted positions and formatting
    for bar, value in zip(bars, data_sorted['mean']):
        rounded_value = round(value / 1000) * 1000  # Round to nearest thousand
        plt.text(bar.get_x() + bar.get_width() / 2, value + 0.05, f'${rounded_value:,.0f}', ha='center', va='bottom', fontsize=8)

    plt.show()

# Specify genres
selected_genres = ['Horror', 'Mystery', 'Thriller', 'Sport', 'Romance', 'Music', 'Sci-Fi', 'Documentary', 'Animation', 'Comedy']

# Exclude 'Missing' genre from the DataFrame
drop_dup_df_genre_filtered = drop_dup_df_genre[drop_dup_df_genre['genres'] != 'Missing']

# Mean Production Budget by Genre for selected genres
production_budget_stats_selected_genres = drop_dup_df_genre_filtered[drop_dup_df_genre_filtered['genres'].isin(selected_genres)].groupby('genres')['production_budget'].agg(['mean', 'median', 'count'])
print("Mean Production Budget by Genre for Selected Genres:")
print(production_budget_stats_selected_genres)

# Create bar plot for mean production budget for selected genres
create_bar_plot(production_budget_stats_selected_genres[['mean']], 'Mean Production Budget', 'Mean Production Budget by Selected Genres')
# Out:
# Mean Production Budget by Genre for Selected Genres:
#                      mean      median  count
# genres
# Animation    1.020059e+08  90000000.0     85
# Comedy       4.254342e+07  29000000.0    415
# Documentary  1.178095e+07   5000000.0     21
# Horror       2.075381e+07  10000000.0    118
# Music        1.957500e+07  17250000.0     36
# Mystery      2.658768e+07  10000000.0     95
# Romance      2.161734e+07  17000000.0    160
# Sci-Fi       9.988978e+07  80000000.0    101
# Sport        3.209524e+07  25000000.0     21
# Thriller     3.851937e+07  25000000.0    193

# %%
# Assuming you have drop_dup_df_genre DataFrame
top_genres = drop_dup_df_genre['genres'].value_counts().nlargest(10).index
filtered_df = drop_dup_df_genre[drop_dup_df_genre['genres'].isin(top_genres)]

# Group by genre and calculate the mean worldwide_gross
worldwide_gross_by_genre = filtered_df.groupby('genres')['worldwide_gross'].mean().reset_index()

# Round the worldwide_gross values to the nearest thousand
worldwide_gross_by_genre['worldwide_gross'] = worldwide_gross_by_genre['worldwide_gross'].round(-3)

# Sort the DataFrame by worldwide_gross in descending order
worldwide_gross_by_genre = worldwide_gross_by_genre.sort_values(by='worldwide_gross', ascending=False)

# Create a color scale for the bars
colors = plt.cm.viridis(worldwide_gross_by_genre['worldwide_gross'] / worldwide_gross_by_genre['worldwide_gross'].max())

# Create a bar plot with worldwide_gross
plt.figure(figsize=(12, 8))
bars = sns.barplot(x='genres', y='worldwide_gross', data=worldwide_gross_by_genre, palette=colors)

# Set labels and title
plt.ylabel('Mean Worldwide Gross ($)')
plt.title('Mean Worldwide Gross by Genre')

# Add value annotations inside each bar (rotated vertically)
for bar, value, color in zip(bars.patches, worldwide_gross_by_genre['worldwide_gross'], colors):
    plt.text(
        bar.get_x() + bar.get_width() / 2,
        bar.get_height() / 2,  # Adjust the position to the center of the bar
        f'${value:,.0f}',  # Use commas for thousands separator
        ha='center',
        va='center',  # Use 'center' for vertical alignment
        rotation='vertical',  # Rotate text vertically
        color='white' if color < 0.7 else 'black'  # Set text color based on bar color
    )

plt.show()
# Out:
# <ipython-input-102-a694c9b3dc3d>:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   bars = sns.barplot(x='genres', y='worldwide_gross', data=worldwide_gross_by_genre, palette=colors)
# <ipython-input-102-a694c9b3dc3d>:19: UserWarning: Numpy array is not a supported type for `palette`. Please convert your palette to a list. This will become an error in v0.14
#   bars = sns.barplot(x='genres', y='worldwide_gross', data=worldwide_gross_by_genre, palette=colors)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-102-a694c9b3dc3d> in <module>
#      32         va='center',  # Use 'center' for vertical alignment
#      33         rotation='vertical',  # Rotate text vertically
# ---> 34         color='white' if color < 0.7 else 'black'  # Set text color based on bar color
#      35     )
#      36
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
import matplotlib.ticker as ticker
# drop_dup_df_genre DataFrame

# Filter genres
selected_genres = ["Horror", "Mystery", "Thriller", "Sport", "Romance", "Music", "Sci-Fi", "Documentary", "Animation", "Comedy"]
filtered_df = drop_dup_df_genre[drop_dup_df_genre['genres'].isin(selected_genres)]

# Group by genre and calculate mean values
mean_values_df = filtered_df.groupby('genres').agg({
    'production_budget': 'mean',
    'roi': 'mean'
}).reset_index()

# Set up color and marker mapping for each genre
genre_color_map = {
    "Horror": 'red',
    "Mystery": 'blue',
    "Thriller": 'green',
    "Sport": 'orange',
    "Romance": 'purple',
    "Music": 'brown',
    "Sci-Fi": 'pink',
    "Documentary": 'gray',
    "Animation": 'cyan',
    "Comedy": 'lime'
}

genre_marker_map = {
    "Horror": 'o',
    "Mystery": 's',
    "Thriller": '^',
    "Sport": 'D',
    "Romance": 'v',
    "Music": 'p',
    "Sci-Fi": '*',
    "Documentary": '>',
    "Animation": '<',
    "Comedy": 'h'
}

# Create scatter plot with different colors and markers for each genre
plt.figure(figsize=(12, 8))
for i, genre in enumerate(selected_genres):
    mean_values = mean_values_df[mean_values_df['genres'] == genre]
    plt.scatter(
        mean_values['production_budget'],
        mean_values['roi'],
        label=genre,
        color=genre_color_map[genre],
        marker=genre_marker_map[genre],
        s=100,  # Adjust marker size
    )

plt.title('Mean ROI vs Mean Production Budget by Genre')
plt.xlabel('Mean Production Budget')
plt.ylabel('Mean ROI')

# Format x-axis ticks as currency
formatter = ticker.StrMethodFormatter("${x:,.0f}")
plt.gca().xaxis.set_major_formatter(formatter)

# Display the legend
plt.legend()

plt.grid(True)
plt.show()

# %%
# drop_dup_df_genre DataFrame

# Filter genres
selected_genres = ["Horror", "Mystery", "Thriller", "Sport", "Romance", "Music", "Sci-Fi", "Documentary", "Animation", "Comedy"]
filtered_df = drop_dup_df_genre[drop_dup_df_genre['genres'].isin(selected_genres)]

# Reset index
filtered_df.reset_index(drop=True, inplace=True)

# Group by genre and calculate mean worldwide gross
mean_worldwide_gross_df = filtered_df.groupby('genres')['worldwide_gross'].mean().reset_index()

# Round mean values to the nearest thousand
mean_worldwide_gross_df['worldwide_gross'] = mean_worldwide_gross_df['worldwide_gross'].round(-3)

# Sort genres by mean worldwide gross in descending order
mean_worldwide_gross_df = mean_worldwide_gross_df.sort_values(by='worldwide_gross', ascending=False)

# Set up color mapping for each genre
genre_color_map = {
    "Horror": 'red',
    "Mystery": 'blue',
    "Thriller": 'green',
    "Sport": 'orange',
    "Romance": 'purple',
    "Music": 'brown',
    "Sci-Fi": 'pink',
    "Documentary": 'gray',
    "Animation": 'cyan',
    "Comedy": 'lime'
}

# Create vertical bar chart with different colors for each genre
plt.figure(figsize=(12, 8))
bar_plot = sns.barplot(x='genres', y='worldwide_gross', data=mean_worldwide_gross_df, order=mean_worldwide_gross_df['genres'], palette=[genre_color_map[genre] for genre in mean_worldwide_gross_df['genres']])

plt.title('Mean Worldwide Gross by Genre')
plt.xlabel('Genre')
plt.ylabel('Mean Worldwide Gross')

plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels for better readability

# Add rounded mean values on top of each bar
for p in bar_plot.patches:
    bar_plot.annotate(f"${p.get_height():,.0f}", (p.get_x() + p.get_width() / 2., p.get_height()),
                      ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
                      textcoords='offset points')

plt.grid(True)
plt.show()
# Out:
# <ipython-input-104-c1205ac8b85a>:35: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   bar_plot = sns.barplot(x='genres', y='worldwide_gross', data=mean_worldwide_gross_df, order=mean_worldwide_gross_df['genres'], palette=[genre_color_map[genre] for genre in mean_worldwide_gross_df['genres']])

# %%
# drop_dup_df_genre DataFrame

# Filter genres
selected_genres = ["Horror", "Mystery", "Thriller", "Sport", "Romance", "Music", "Sci-Fi", "Documentary", "Animation", "Comedy"]
filtered_df = drop_dup_df_genre[drop_dup_df_genre['genres'].isin(selected_genres)]

# Reset index
filtered_df.reset_index(drop=True, inplace=True)

# Group by genre and calculate mean production budget
mean_production_budget_df = filtered_df.groupby('genres')['production_budget'].mean().reset_index()

# Round mean values to the nearest thousand
mean_production_budget_df['production_budget'] = mean_production_budget_df['production_budget'].round(-3)

# Sort genres by mean production budget in descending order
mean_production_budget_df = mean_production_budget_df.sort_values(by='production_budget', ascending=False)

# Set up color mapping for each genre
genre_color_map = {
    "Horror": 'red',
    "Mystery": 'blue',
    "Thriller": 'green',
    "Sport": 'orange',
    "Romance": 'purple',
    "Music": 'brown',
    "Sci-Fi": 'pink',
    "Documentary": 'gray',
    "Animation": 'cyan',
    "Comedy": 'lime'
}

# Create vertical bar chart with different colors for each genre
plt.figure(figsize=(12, 8))
bar_plot = sns.barplot(x='genres', y='production_budget', data=mean_production_budget_df, order=mean_production_budget_df['genres'], palette=[genre_color_map[genre] for genre in mean_production_budget_df['genres']])

plt.title('Mean Production Budget by Genre')
plt.xlabel('Genre')
plt.ylabel('Mean Production Budget')

plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels for better readability

# Add rounded mean values on top of each bar
for p in bar_plot.patches:
    bar_plot.annotate(f"${p.get_height():,.0f}", (p.get_x() + p.get_width() / 2., p.get_height()),
                      ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
                      textcoords='offset points')

plt.grid(True)
plt.show()
# Out:
# <ipython-input-105-eac188707fa1>:35: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   bar_plot = sns.barplot(x='genres', y='production_budget', data=mean_production_budget_df, order=mean_production_budget_df['genres'], palette=[genre_color_map[genre] for genre in mean_production_budget_df['genres']])

# %%
#THIS ONE LOOKS LIKE ITS CORRECT, NEED TO DOUBLE CHECK!
# Assuming 'drop_dup_df_ex_prof' DataFrame is defined

# Filter the DataFrame for the 'Horror' genre
horror_df = drop_dup_df_ex_prof[drop_dup_df_ex_prof['genres'].apply(lambda x: 'Horror' in x)]

# Filter for rows where 'primary_profession' is 'director'
horror_directors_df = horror_df[horror_df['primary_profession'] == 'director']

# Group by 'primary_name' (director) and aggregate to get the total worldwide gross and film count for each director
directors_by_horror = horror_directors_df.groupby('primary_name').agg({
    'worldwide_gross': 'sum',
    'primary_title': 'count'
}).reset_index()

# Rename the columns for clarity
directors_by_horror.columns = ['Director', 'Total Worldwide Gross', 'Film Count']

# Sort the DataFrame by 'Total Worldwide Gross' in descending order and take the top 5 directors
top_horror_directors = directors_by_horror.sort_values(by='Total Worldwide Gross', ascending=False).head(5)

# Print the result
print("Top 5 Directors for Horror Genre by Worldwide Gross:")
print(top_horror_directors)
# Out:
# Top 5 Directors for Horror Genre by Worldwide Gross:
#              Director  Total Worldwide Gross  Film Count
# 1     Andy Muschietti            697460000.0           1
# 12  David F. Sandberg            305380000.0           1
# 36       Tod Williams            177510000.0           1
# 33       Steven Quale            155010000.0           1
# 21       Joe Johnston            142630000.0           1

# %%
#DON'T USE, MESSY. FOR REFERENCE.
# 'drop_dup_df' DataFrame 

# Filter for 'Horror' genre
horror_df = drop_dup_df[
    (drop_dup_df['genres'].apply(lambda x: 'Horror' in x)) & 
    (drop_dup_df['primary_profession'].apply(lambda x: 'director' in x if isinstance(x, list) else False))
]

# Print the intermediate results
print("Horror movies directed by anyone:")
print(horror_df[['primary_name', 'primary_title', 'worldwide_gross']])

# Group by 'person_id' (director) and aggregate to get the total worldwide gross and film count for each director
directors_by_horror = horror_df.groupby('person_id').agg({
    'worldwide_gross': 'sum',
    'primary_title': 'nunique'
}).reset_index()

# Merge with the original DataFrame to get 'primary_name'
directors_by_horror = pd.merge(directors_by_horror, drop_dup_df[['person_id', 'primary_name']], on='person_id')

# Rename the columns for clarity
directors_by_horror.columns = ['Person ID', 'Total Worldwide Gross', 'Film Count', 'Director']

# Sort the DataFrame by 'Total Worldwide Gross' in descending order and take the top 10 directors
directors_by_horror = directors_by_horror.sort_values(by='Total Worldwide Gross', ascending=False).head(10)

# Print the final results
print("\nTop 10 Horror Directors:")
print(directors_by_horror[['Director', 'Film Count', 'Total Worldwide Gross']])
# Out:
# Horror movies directed by anyone:
#               primary_name                          primary_title  \
# 148           Tod Williams                  paranormal activity 2
# 179           Joe Johnston                            the wolfman
# 279           Daniel Stamm                      the last exorcism
# 292      John Erick Dowdle                                  devil
# 311           Breck Eisner                            the crazies
# 539   Michael Winterbottom                   the killer inside me
# 1164          Steven Quale                    final destination 5
# 1269   Catherine Hardwicke                        red riding hood
# 1532            Troy Nixey            don't be afraid of the dark
# 2029       Quentin Dupieux                                 rubber
# 2354         James Watkins                     the woman in black
# 2382    William Brent Bell                       the devil inside
# 2637          Todd Lincoln                         the apparition
# 3037          Ben Wheatley                              kill list
# 3200               Ti West                         the innkeepers
# 3554          Harald Zwart  the mortal instruments: city of bones
# 3597         Brad Anderson                               the call
# 3643       John Luessenhop                      texas chainsaw 3d
# 3992          Adam Wingard                            you're next
# 4003      Ed Gass-Donnelly              the last exorcism part ii
# 5537          Daniel Stamm                                13 sins
# 5896       Levan Gabriadze                             unfriended
# 5913    David M. Rosenthal                        the perfect guy
# 5919            Ciarán Foy                             sinister 2
# 5993         Paul McGuigan                    victor frankenstein
# 7044    Jaume Collet-Serra                           the shallows
# 7066      Dan Trachtenberg                    10 cloverfield lane
# 7204          Adam Wingard                            blair witch
# 7213          Shan Serafin                             the forest
# 7299           Burr Steers        pride and prejudice and zombies
# 7453           D.J. Caruso               the disappointments room
# 7670          Karyn Kusama                         the invitation
# 8225       Andy Muschietti                                     it
# 8288     David F. Sandberg                    annabelle: creation
# 8413         Peter Spierig                                 jigsaw
# 8435   F. Javier Gutiérrez                                  rings
# 8583           Stacy Title                        the bye bye man
# 9303       Gerard McMurray                        the first purge
# 9388             Ari Aster                             hereditary
# 9459         Sylvain White                            slender man
# 9478  Diederik Van Rooijen         the possession of hannah grace
# 9608       Luca Guadagnino                               suspiria
#
#       worldwide_gross
# 148       177510000.0
# 179       142630000.0
# 279        70170000.0
# 292        63350000.0
# 311        56450000.0
# 539         3620000.0
# 1164      155010000.0
# 1269       91680000.0
# 1532       39130000.0
# 2029         680000.0
# 2354      128960000.0
# 2382      101760000.0
# 2637       10640000.0
# 3037         460000.0
# 3200        1010000.0
# 3554       75970000.0
# 3597       69820000.0
# 3643       47670000.0
# 3992       26890000.0
# 4003       25450000.0
# 5537          50000.0
# 5896       64360000.0
# 5913       60280000.0
# 5919       54100000.0
# 5993       31120000.0
# 7044      118760000.0
# 7066      108290000.0
# 7204       38990000.0
# 7213       40750000.0
# 7299       16640000.0
# 7453        3500000.0
# 7670         350000.0
# 8225      697460000.0
# 8288      305380000.0
# 8413      102450000.0
# 8435       82920000.0
# 8583       31190000.0
# 9303      136620000.0
# 9388       70130000.0
# 9459       51720000.0
# 9478       42790000.0
# 9608        7030000.0
#
# Top 10 Horror Directors:
#               Director  Film Count  Total Worldwide Gross
# 17     Andy Muschietti           1            697460000.0
# 51   David F. Sandberg           1            305380000.0
# 25        Tod Williams           1            177510000.0
# 18        Steven Quale           1            155010000.0
# 1         Joe Johnston           1            142630000.0
# 0         Joe Johnston           1            142630000.0
# 53     Gerard McMurray           1            136620000.0
# 32       James Watkins           1            128960000.0
# 47  Jaume Collet-Serra           1            118760000.0
# 46  Jaume Collet-Serra           1            118760000.0

# %%
#THIS IS CORRECT. USE THIS.
#'drop_dup_df' DataFrame

# Filter for 'Horror' genre and 'director' profession
horror_director_df = drop_dup_df[
    (drop_dup_df['genres'].apply(lambda x: 'Horror' in x)) & 
    (drop_dup_df['primary_profession'].apply(lambda x: 'director' in x if isinstance(x, list) else False))
]

# Group by 'primary_name' (director) and aggregate to get the total worldwide gross and film count for each director
directors_by_horror = horror_director_df.groupby('primary_name').agg({
    'worldwide_gross': 'sum',
    'primary_title': 'nunique'
}).reset_index()

# Rename the columns for clarity
directors_by_horror.columns = ['Director', 'Total Worldwide Gross', 'Film Count']

# Sort the DataFrame by 'Total Worldwide Gross' in descending order and take the top 5 directors
top_horror_directors = directors_by_horror.sort_values(by='Total Worldwide Gross', ascending=False).head(5)

# Print the result
print("\nTop 5 Directors for Horror Genre by Worldwide Gross:")
print(top_horror_directors)
# Out:
# Top 5 Directors for Horror Genre by Worldwide Gross:
#              Director  Total Worldwide Gross  Film Count
# 1     Andy Muschietti            697460000.0           1
# 12  David F. Sandberg            305380000.0           1
# 36       Tod Williams            177510000.0           1
# 33       Steven Quale            155010000.0           1
# 21       Joe Johnston            142630000.0           1

# %%
#USE THIS
# Assuming 'drop_dup_df' DataFrame is defined

# Filter the DataFrame for the 'Thriller' genre and 'director' profession
thriller_director_df = drop_dup_df[
    (drop_dup_df['genres'].apply(lambda x: 'Thriller' in x)) & 
    (drop_dup_df['primary_profession'].apply(lambda x: 'director' in x if isinstance(x, list) else False))
]

# Group by 'primary_name' (director) and aggregate to get the total worldwide gross and film count for each director
directors_by_thriller = thriller_director_df.groupby('primary_name').agg({
    'worldwide_gross': 'sum',
    'primary_title': 'nunique'
}).reset_index()

# Rename the columns for clarity
directors_by_thriller.columns = ['Director', 'Total Worldwide Gross', 'Film Count']

# Sort the DataFrame by 'Total Worldwide Gross' in descending order and take the top 5 directors
top_thriller_directors = directors_by_thriller.sort_values(by='Total Worldwide Gross', ascending=False).head(5)

# Print the result
print("\nTop 5 Directors for Thriller Genre by Worldwide Gross:")
print(top_thriller_directors)
# Out:
# Top 5 Directors for Thriller Genre by Worldwide Gross:
#               Director  Total Worldwide Gross  Film Count
# 25        F. Gary Gray           1.234850e+09           1
# 55     Olivier Megaton           7.777700e+08           3
# 57     Paul Greengrass           7.343400e+08           3
# 4      Andy Muschietti           6.974600e+08           1
# 32  Jaume Collet-Serra           6.462100e+08           5

# %%
#THIS IS CORRECT
# 'drop_dup_df' DataFrame

# Filter the DataFrame for the 'Mystery' genre and 'director' profession
mystery_director_df = drop_dup_df[
    (drop_dup_df['genres'].apply(lambda x: 'Mystery' in x)) & 
    (drop_dup_df['primary_profession'].apply(lambda x: 'director' in x if isinstance(x, list) else False))
]

# Group by 'primary_name' (director) and aggregate to get the total worldwide gross and film count for each director
directors_by_mystery = mystery_director_df.groupby('primary_name').agg({
    'worldwide_gross': 'sum',
    'primary_title': 'nunique'
}).reset_index()

# Rename the columns for clarity
directors_by_mystery.columns = ['Director', 'Total Worldwide Gross', 'Film Count']

# Sort the DataFrame by 'Total Worldwide Gross' in descending order and take the top 5 directors
top_mystery_directors = directors_by_mystery.sort_values(by='Total Worldwide Gross', ascending=False).head(5)

# Print the result
print("\nTop 5 Directors for Mystery Genre by Worldwide Gross:")
print(top_mystery_directors)
# Out:
# Top 5 Directors for Mystery Genre by Worldwide Gross:
#               Director  Total Worldwide Gross  Film Count
# 7        David Fincher            607940000.0           2
# 10    Denis Villeneuve            575890000.0           3
# 15  Jaume Collet-Serra            460490000.0           3
# 25         Neil Burger            431570000.0           2
# 21     Louis Leterrier            342770000.0           1

# %%
#USE THIS
# 'drop_dup_df' DataFrame

# Filter the DataFrame for the 'Horror' genre and 'director' profession
horror_director_df = drop_dup_df[
    (drop_dup_df['genres'].apply(lambda x: 'Horror' in x)) & 
    (drop_dup_df['primary_profession'].apply(lambda x: 'director' in x if isinstance(x, list) else False))
]

# Group by 'primary_name' (director) and aggregate to get the mean ROI and film count for each director
directors_by_horror_roi = horror_director_df.groupby('primary_name').agg({
    'roi': 'mean',
    'primary_title': 'nunique'
}).reset_index()

# Rename the columns for clarity
directors_by_horror_roi.columns = ['Director', 'Mean ROI', 'Film Count']

# Sort the DataFrame by 'Mean ROI' in descending order and take the top 5 directors
top_horror_directors_roi = directors_by_horror_roi.sort_values(by='Mean ROI', ascending=False).head(5)

# Print the result
print("\nTop 5 Directors for Horror Genre by ROI:")
print(top_horror_directors_roi)
# Out:
# Top 5 Directors for Horror Genre by ROI:
#               Director    Mean ROI  Film Count
# 39  William Brent Bell  100.760000           1
# 25     Levan Gabriadze   63.360000           1
# 36        Tod Williams   58.170000           1
# 10    Dan Trachtenberg   20.658000           1
# 12   David F. Sandberg   19.358667           1

# %%
#USE THIS
# Assuming 'drop_dup_df' DataFrame is defined

# Filter the DataFrame for the 'Thriller' genre and 'director' profession
thriller_director_df = drop_dup_df[
    (drop_dup_df['genres'].apply(lambda x: 'Thriller' in x)) & 
    (drop_dup_df['primary_profession'].apply(lambda x: 'director' in x if isinstance(x, list) else False))
]

# Group by 'primary_name' (director) and aggregate to get the mean ROI and film count for each director
directors_by_thriller_roi = thriller_director_df.groupby('primary_name').agg({
    'roi': 'mean',
    'primary_title': 'nunique'
}).reset_index()

# Rename the columns for clarity
directors_by_thriller_roi.columns = ['Director', 'Mean ROI', 'Film Count']

# Sort the DataFrame by 'Mean ROI' in descending order and take the top 5 directors
top_thriller_directors_roi = directors_by_thriller_roi.sort_values(by='Mean ROI', ascending=False).head(5)

# Print the result
print("\nTop 5 Directors for Thriller Genre by ROI:")
print(top_thriller_directors_roi)
# Out:
# Top 5 Directors for Thriller Genre by ROI:
#              Director   Mean ROI  Film Count
# 46    Levan Gabriadze  63.360000           1
# 19  David F. Sandberg  19.358667           1
# 4     Andy Muschietti  18.927429           1
# 17       Daniel Stamm  18.497917           2
# 52      Morten Tyldum  14.182667           1

# %%
# 'drop_dup_df' DataFrame

# Filter the DataFrame for the 'Mystery' genre and 'director' profession
mystery_director_df = drop_dup_df[
    (drop_dup_df['genres'].apply(lambda x: 'Mystery' in x)) & 
    (drop_dup_df['primary_profession'].apply(lambda x: 'director' in x if isinstance(x, list) else False))
]

# Group by 'primary_name' (director) and aggregate to get the mean ROI and film count for each director
directors_by_mystery_roi = mystery_director_df.groupby('primary_name').agg({
    'roi': 'mean',
    'primary_title': 'nunique'
}).reset_index()

# Rename the columns for clarity
directors_by_mystery_roi.columns = ['Director', 'Mean ROI', 'Film Count']

# Sort the DataFrame by 'Mean ROI' in descending order and take the top 5 directors
top_mystery_directors_roi = directors_by_mystery_roi.sort_values(by='Mean ROI', ascending=False).head(5)

# Print the result
print("\nTop 5 Directors for Mystery Genre by ROI:")
print(top_mystery_directors_roi)
# Out:
# Top 5 Directors for Mystery Genre by ROI:
#              Director   Mean ROI  Film Count
# 20    Levan Gabriadze  63.360000           1
# 5    Dan Trachtenberg  20.658000           1
# 6   David F. Sandberg  19.358667           1
# 26      Peter Spierig   9.245000           1
# 9        Debra Granik   7.065000           1

# %%
# Explode the 'genres' column to individual rows
exploded_df = drop_dup_df.explode('genres')

# Print unique values in 'genres' column
print("Unique values in 'genres' column:")
print(exploded_df['genres'].unique())
# Out:
# Unique values in 'genres' column:
# ['Adventure' 'Animation' 'Comedy' 'Missing' 'Action' 'Sci-Fi' 'Drama'
#  'Fantasy' 'Family' 'Thriller' 'Romance' 'Horror' 'Mystery' 'Western'
#  'Biography' 'Crime' 'Sport' 'War' 'Music' 'Musical' 'Documentary'
#  'History']

# %%
# Convert 'release_date' to datetime
drop_dup_df['release_date'] = pd.to_datetime(drop_dup_df['release_date'])

# Extract month, day, and year
drop_dup_df['Month'] = drop_dup_df['release_date'].dt.month

# Filter for "Horror" genre
horror_df = drop_dup_df[drop_dup_df['genres'].apply(lambda x: 'Horror' in x)]

# Group by month and calculate count, mean worldwide gross, and mean ROI
horror_monthly_stats = horror_df.groupby('Month').agg({
    'worldwide_gross': ['count', 'mean'],
    'roi': 'mean'
}).reset_index()

# Rename the columns for clarity
horror_monthly_stats.columns = ['Month', 'Film Count', 'Mean Worldwide Gross', 'Mean ROI']

# Print the result
print("Horror Genre Monthly Statistics:")
print(horror_monthly_stats)
# Out:
# Horror Genre Monthly Statistics:
#     Month  Film Count  Mean Worldwide Gross   Mean ROI
# 0     1.0          11          9.595727e+07  15.140176
# 1     2.0          12          7.550583e+07   7.367231
# 2     3.0           7          4.990571e+07   8.297340
# 3     4.0          13          4.014077e+07  12.592835
# 4     5.0           5          1.062120e+08   8.882172
# 5     6.0           8          1.208000e+08   5.699537
# 6     7.0           9          9.425444e+07  53.223125
# 7     8.0          12          1.237608e+08   8.710899
# 8     9.0          15          1.010773e+08   3.674906
# 9    10.0          17          8.953882e+07  15.297286
# 10   11.0           6          4.399000e+07   1.872458
# 11   12.0           3          4.466333e+07   1.599598
# <ipython-input-115-15e4a3334112>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   drop_dup_df['release_date'] = pd.to_datetime(drop_dup_df['release_date'])
# <ipython-input-115-15e4a3334112>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   drop_dup_df['Month'] = drop_dup_df['release_date'].dt.month

# %%
# !pip install tabulate

# %%
from tabulate import tabulate

# ... (previous code remains unchanged)
# Convert 'release_date' to datetime
drop_dup_df['release_date'] = pd.to_datetime(drop_dup_df['release_date'])

# Extract month, day, and year
drop_dup_df['Month'] = drop_dup_df['release_date'].dt.month

# Filter for "Horror" genre
horror_df = drop_dup_df[drop_dup_df['genres'].apply(lambda x: 'Horror' in x)]

# Group by month and calculate count, mean worldwide gross, and mean ROI
horror_monthly_stats = horror_df.groupby('Month').agg({
    'worldwide_gross': ['count', 'mean'],
    'roi': 'mean'
}).reset_index()

# Rename the columns for clarity
horror_monthly_stats.columns = ['Month', 'Film Count', 'Mean Worldwide Gross', 'Mean ROI']


# Round the values for formatting
horror_monthly_stats['Mean Worldwide Gross'] = horror_monthly_stats['Mean Worldwide Gross'].apply(lambda x: round(x))
horror_monthly_stats['Mean ROI'] = horror_monthly_stats['Mean ROI'].apply(lambda x: round(x, 2))

# Print the result in a clean table with adjusted formatting
table = tabulate(horror_monthly_stats, headers='keys', tablefmt='grid', showindex=False)
print("Horror Genre Monthly Statistics:")
print(table)
# Out:
# Horror Genre Monthly Statistics:
# +---------+--------------+------------------------+------------+
# |   Month |   Film Count |   Mean Worldwide Gross |   Mean ROI |
# +=========+==============+========================+============+
# |       1 |           11 |            9.59573e+07 |      15.14 |
# +---------+--------------+------------------------+------------+
# |       2 |           12 |            7.55058e+07 |       7.37 |
# +---------+--------------+------------------------+------------+
# |       3 |            7 |            4.99057e+07 |       8.3  |
# +---------+--------------+------------------------+------------+
# |       4 |           13 |            4.01408e+07 |      12.59 |
# +---------+--------------+------------------------+------------+
# |       5 |            5 |            1.06212e+08 |       8.88 |
# +---------+--------------+------------------------+------------+
# |       6 |            8 |            1.208e+08   |       5.7  |
# +---------+--------------+------------------------+------------+
# |       7 |            9 |            9.42544e+07 |      53.22 |
# +---------+--------------+------------------------+------------+
# |       8 |           12 |            1.23761e+08 |       8.71 |
# +---------+--------------+------------------------+------------+
# |       9 |           15 |            1.01077e+08 |       3.67 |
# +---------+--------------+------------------------+------------+
# |      10 |           17 |            8.95388e+07 |      15.3  |
# +---------+--------------+------------------------+------------+
# |      11 |            6 |            4.399e+07   |       1.87 |
# +---------+--------------+------------------------+------------+
# |      12 |            3 |            4.46633e+07 |       1.6  |
# +---------+--------------+------------------------+------------+
# <ipython-input-116-83e28952f8be>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   drop_dup_df['release_date'] = pd.to_datetime(drop_dup_df['release_date'])
# <ipython-input-116-83e28952f8be>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   drop_dup_df['Month'] = drop_dup_df['release_date'].dt.month

# %%
# Convert 'release_date' to datetime
drop_dup_df['release_date'] = pd.to_datetime(drop_dup_df['release_date'])

# Extract month, day, and year
drop_dup_df['Month'] = drop_dup_df['release_date'].dt.month

# Filter for "Thriller" genre
thriller_df = drop_dup_df[drop_dup_df['genres'].apply(lambda x: 'Thriller' in x)]

# Group by month and calculate count, mean worldwide gross, and mean ROI
thriller_monthly_stats = thriller_df.groupby('Month').agg({
    'worldwide_gross': ['count', 'mean'],
    'roi': 'mean'
}).reset_index()

# Rename the columns for clarity
thriller_monthly_stats.columns = ['Month', 'Film Count', 'Mean Worldwide Gross', 'Mean ROI']


# Round the values for formatting
thriller_monthly_stats['Mean Worldwide Gross'] = thriller_monthly_stats['Mean Worldwide Gross'].apply(lambda x: round(x))
thriller_monthly_stats['Mean ROI'] = thriller_monthly_stats['Mean ROI'].apply(lambda x: round(x, 2))

# Print the result in a clean table with adjusted formatting
table = tabulate(thriller_monthly_stats, headers='keys', tablefmt='grid', showindex=False)
print("Thriller Genre Monthly Statistics:")
print(table)
# Out:
# Thriller Genre Monthly Statistics:
# +---------+--------------+------------------------+------------+
# |   Month |   Film Count |   Mean Worldwide Gross |   Mean ROI |
# +=========+==============+========================+============+
# |       1 |           16 |            7.95188e+07 |       4.04 |
# +---------+--------------+------------------------+------------+
# |       2 |           20 |            1.47847e+08 |       5.09 |
# +---------+--------------+------------------------+------------+
# |       3 |           13 |            1.04785e+08 |       1.83 |
# +---------+--------------+------------------------+------------+
# |       4 |           12 |            3.1478e+08  |      14.16 |
# +---------+--------------+------------------------+------------+
# |       5 |            6 |            1.2185e+08  |       8.35 |
# +---------+--------------+------------------------+------------+
# |       6 |            9 |            1.05424e+08 |       5.31 |
# +---------+--------------+------------------------+------------+
# |       7 |           15 |            2.18956e+08 |      30.31 |
# +---------+--------------+------------------------+------------+
# |       8 |           22 |            9.88795e+07 |       4.1  |
# +---------+--------------+------------------------+------------+
# |       9 |           22 |            9.76136e+07 |       2.53 |
# +---------+--------------+------------------------+------------+
# |      10 |           35 |            1.26325e+08 |       7.4  |
# +---------+--------------+------------------------+------------+
# |      11 |           14 |            2.01393e+08 |       2.86 |
# +---------+--------------+------------------------+------------+
# |      12 |            9 |            1.30771e+08 |       3.69 |
# +---------+--------------+------------------------+------------+
# <ipython-input-117-a6ce5dec99b8>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   drop_dup_df['release_date'] = pd.to_datetime(drop_dup_df['release_date'])
# <ipython-input-117-a6ce5dec99b8>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   drop_dup_df['Month'] = drop_dup_df['release_date'].dt.month

# %%
# Convert 'release_date' to datetime
drop_dup_df['release_date'] = pd.to_datetime(drop_dup_df['release_date'])

# Extract month, day, and year
drop_dup_df['Month'] = drop_dup_df['release_date'].dt.month

# Filter for "Thriller" genre
mystery_df = drop_dup_df[drop_dup_df['genres'].apply(lambda x: 'Mystery' in x)]

# Group by month and calculate count, mean worldwide gross, and mean ROI
mystery_monthly_stats = mystery_df.groupby('Month').agg({
    'worldwide_gross': ['count', 'mean'],
    'roi': 'mean'
}).reset_index()

# Rename the columns for clarity
mystery_monthly_stats.columns = ['Month', 'Film Count', 'Mean Worldwide Gross', 'Mean ROI']


# Round the values for formatting
mystery_monthly_stats['Mean Worldwide Gross'] = mystery_monthly_stats['Mean Worldwide Gross'].apply(lambda x: round(x))
mystery_monthly_stats['Mean ROI'] = mystery_monthly_stats['Mean ROI'].apply(lambda x: round(x, 2))

# Print the result in a clean table with adjusted formatting
table = tabulate(mystery_monthly_stats, headers='keys', tablefmt='grid', showindex=False)
print("Mystery Genre Monthly Statistics:")
print(table)
# Out:
# Mystery Genre Monthly Statistics:
# +---------+--------------+------------------------+------------+
# |   Month |   Film Count |   Mean Worldwide Gross |   Mean ROI |
# +=========+==============+========================+============+
# |       1 |            8 |            7.757e+07   |       5.37 |
# +---------+--------------+------------------------+------------+
# |       2 |           10 |            1.15443e+08 |       7.89 |
# +---------+--------------+------------------------+------------+
# |       3 |           12 |            6.12017e+07 |       4.76 |
# +---------+--------------+------------------------+------------+
# |       4 |            8 |            4.676e+07   |      17.73 |
# +---------+--------------+------------------------+------------+
# |       5 |            3 |            3.2388e+08  |      17.1  |
# +---------+--------------+------------------------+------------+
# |       6 |            8 |            1.10934e+08 |       2.4  |
# +---------+--------------+------------------------+------------+
# |       7 |            7 |            1.21529e+08 |      64.94 |
# +---------+--------------+------------------------+------------+
# |       8 |            4 |            1.23532e+08 |       8.22 |
# +---------+--------------+------------------------+------------+
# |       9 |            8 |            8.93588e+07 |       4.52 |
# +---------+--------------+------------------------+------------+
# |      10 |           21 |            1.04312e+08 |      10.04 |
# +---------+--------------+------------------------+------------+
# |      11 |            3 |            8.576e+07   |       3.2  |
# +---------+--------------+------------------------+------------+
# |      12 |            3 |            1.29367e+08 |       0.7  |
# +---------+--------------+------------------------+------------+
# <ipython-input-118-6e30a3d6bc12>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   drop_dup_df['release_date'] = pd.to_datetime(drop_dup_df['release_date'])
# <ipython-input-118-6e30a3d6bc12>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   drop_dup_df['Month'] = drop_dup_df['release_date'].dt.month
